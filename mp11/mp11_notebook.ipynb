# %% [markdown]
# # CS440/ECE448 Spring 2023
# # MP11: Reinforcement Learning

# %% [markdown]
# The first thing you need to do is to download this file: <a href="mp11.zip">mp11.zip</a>.  If you want, you can also download <a href="mp11_extra.zip">mp11_extra.zip</a>, the extra credit assignment.  `mp11.zip` has the following content:
#
# * `submitted.py`: Your homework. Edit, and then submit to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
# * `mp11_notebook.ipynb`: This is a <a href="https://anaconda.org/anaconda/jupyter">Jupyter</a> notebook to help you debug.  You can completely ignore it if you want, although you might find that it gives you useful instructions.
# * `pong.py`: This is a program that plays Pong.  If called interactively, it will call the module `pong_display.py` to create a display, so that you can play.  If told to use a Q-learner, it will call your `submitted.py` to do Q-learning.
# * `grade.py`: Once your homework seems to be working, you can test it by typing `python grade.py`, which will run the tests in `tests/tests_visible.py`.
# * `tests/test_visible.py`: This file contains about half of the <a href="https://docs.python.org/3/library/unittest.html">unit tests</a> that Gradescope will run in order to grade your homework.  If you can get a perfect score on these tests, then you should also get a perfect score on the additional hidden tests that Gradescope uses.
# * `requirements.txt`: This tells you which python packages you need to have installed, in order to run `grade.py`.  You can install all of those packages by typing `pip install -r requirements.txt` or `pip3 install -r requirements.txt`.

# %% [markdown]
# This file (`mp11_notebook.ipynb`) will walk you through the whole MP, giving you instructions and debugging tips as you go.
#
# ### Table of Contents
#
# 1. <a href="#section1">Playing Pong</a>
# 1. <a href="#section2">Creating a Q-Learner Object</a>
# 1. <a href="#section3">Epsilon-First Exploration</a>
# 1. <a href="#section4">Q-Learning</a>
# 1. <a href="#section5">Saving and Loading Your Q and N Tables</a>
# 1. <a href="#section6">Exploitation</a>
# 1. <a href="#section7">Acting</a>
# 1. <a href="#section8">Training</a>
# 1. <a href="#section9">Extra Credit</a>
# 1. <a href="#grade">Grade Your Homework</a>

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## Playing Pong

# %% [markdown]
# Pong was the <a href="https://en.wikipedia.org/wiki/Pong">first video game produced by Atari.</a>  It is a simple game, based on table tennis.  Here is a two-person version of the game: https://commons.wikimedia.org/wiki/File:Pong_Game_Test2.gif
#
# We will be playing a one-person version of the game:
#
# * When the ball hits the top, bottom, or left wall of the playing field, it bounces.
# * The right end of the playing field is open, except for the paddle.  If the ball hits the paddle, it bounces, and the player's score increments by one.  If the ball hits the open space, the game is over; the score resets to zero, and a new game begins.
#
# The game is pretty simple, but in order to get a better feeling for it, you may want to try playing it yourself.  Use the up arrow to move the paddle upward, and the down arrow to move the paddle downward.  See how high you can make your score:

# %%
# !python3 pong.py
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.10.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# Once you figure out how to use the arrow keys to control your paddle, we hope you will find that the game is not too hard for a human to play.  However, for a computer, it's difficult to know: where should the paddle be moved at each time step?  In order to see how difficult it is for a computer to play, let's ask the "random" player to play the game.
#
# **WARNING:** The following line will open a pygame window.  The pygame window will be hidden by this window -- in order to see it, you will need to minimize this window.  The pygame window will consume a lot of CPU time just waiting for the processor, so in order to kill it, you will need to come back to this window, click on the block below, then click the Jupyter "stop" button (the square button at the top of this window) in order to stop processing.

# %%
# !python3 pong.py --player random
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.10.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ^C
# Traceback (most recent call last):
#   File "/Users/ethanyyx/Documents/CS440/mp11/pong.py", line 270, in <module>
#     application.run()
#   File "/Users/ethanyyx/Documents/CS440/mp11/pong.py", line 170, in run
#     self.display.update_display()
#   File "/Users/ethanyyx/Documents/CS440/mp11/pong_display.py", line 65, in update_display
#     self.fps.tick(60)
# KeyboardInterrupt

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## Creating a Q-Learner Object

# %% [markdown]
# The first thing you will do is to create a `q_learner` object that can store your learned Q table and your N table (table of exploration counts).
#
# Like any other object-oriented language, python permits you to create new object classes in order to store data that will be needed from time to time.  If you are not already very, very familiar with python classes, you might want to study the python class tutorial: https://docs.python.org/3/tutorial/classes.html
#
# Like any other object in python, a `q_learner` object is created by calling its name as a function, e.g., `my_q_learner=submitted.q_learner()`.  Doing so calls the function `submitted.q_learner.__init__()`.  Let's look at the docstring to see what it should do.

# %%
import submitted, importlib
importlib.reload(submitted)
help(submitted.q_learner.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst, state_cardinality)
#     Create a new q_learner object.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a Q table and an N table.
#     Q[...state..., ...action...] = expected utility of state/action pair.
#     N[...state..., ...action...] = # times state/action has been explored.
#     Both are initialized to all zeros.
#     Up to you: how will you encode the state and action in order to
#     define these two lookup tables?  The state will be a list of 5 integers,
#     such that 0 <= state[i] < state_cardinality[i] for 0 <= i < 5.
#     The action will be either -1, 0, or 1.
#     It is up to you to decide how to convert an input state and action
#     into indices that you can use to access your stored Q and N tables.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#     state_cardinality (list) - cardinality of each of the quantized state variables
#
#     @return:
#     None

# %% [markdown]
# Write your `__init__` function to meet the requirements specified in the docstring.  Once you have completed it, the following code should run without errors:

# %%
importlib.reload(submitted)

q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])

print(q_learner)
# Out:
# <submitted.q_learner object at 0x29c793640>

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ## Epsilon-First Exploration

# %% [markdown]
# In order to manage the exploration/exploitation tradeoff, we will be using both "epsilon-first" and "epsilon-greedy" (https://en.wikipedia.org/wiki/Multi-armed_bandit#Semi-uniform_strategies).
#
# The epsilon-first strategy explores every state/action pair at least `nfirst` times before it ever starts to exploit any strategy.  Your `q_learner` should have a table to keep track of how many times it has explored a state/action pair prior to the start of any exploitation.  The method for storing that table is up to you; in order to have some standardized API, therefore, you need to write a method called `report_exploration_counts` that returns a list of the three exploration counts for a given state.

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_exploration_counts)
# Out:
# Help on function report_exploration_counts in module submitted:
#
# report_exploration_counts(self, state)
#     Check to see how many times each action has been explored in this state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     explored_count (array of 3 ints):
#       number of times that each action has been explored from this state.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# Write `report_exploration_counts` so that it returns a list or array for any given state.  Test your code with the following:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('This is how many times state [0,0,0,0,0] has been explored so far:')
print(q_learner.report_exploration_counts([0,0,0,0,0]))
print('This is how many times state [9,9,1,1,9] has been explored so far:')
print(q_learner.report_exploration_counts([9,9,1,1,9]))
# Out:
# This is how many times state [0,0,0,0,0] has been explored so far:
# [0. 0. 0.]
# This is how many times state [9,9,1,1,9] has been explored so far:
# [0. 0. 0.]

# %% [markdown]
# When your learner first starts learning, it will call the function `choose_unexplored_action` to choose an unexplored action.  This function should choose a function uniformly at random from the set of unexplored actions in a given state, if there are any:

# %%
importlib.reload(submitted)
help(submitted.q_learner.choose_unexplored_action)
# Out:
# Help on function choose_unexplored_action in module submitted:
#
# choose_unexplored_action(self, state)
#     Choose an action that has been explored less than nfirst times.
#     If many actions are underexplored, you should choose uniformly
#     from among those actions; don't just choose the first one all
#     the time.
#
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar): either -1, or 0, or 1, or None
#       If all actions have been explored at least n_explore times, return None.
#       Otherwise, choose one uniformly at random from those w/count less than n_explore.
#       When you choose an action, you should increment its count in your counter table.

# %% [markdown]
# If this has been written correctly, the following block should generate a random sequence of actions.  If the next block produces the same action 5 times in a row, that is the wrong result, and the result would be that your code does not pass the autograder.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: -1
# Next action: 1
# Next action: -1
# Next action: 0
# Next action: 1

# %% [markdown]
# After all three actions have been explored `nfirst` times, the function `choose_unexplored_action` should return `None`, as shown here:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,1,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: 1
# Next action: 0
# Next action: -1
# Next action: None

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## Q-Learning

# %% [markdown]
# The reinforcement learning we are implementing is called Q-learning (https://en.wikipedia.org/wiki/Q-learning).
#
# Q-learning keeps a table $Q[s,a]$ that specifies the expected utility of action $a$ in state $s$.  The organization of this table is up to you.  In order to have a standard API, the first thing you should implement is a function `report_q` with the following docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_q)
# Out:
# Help on function report_q in module submitted:
#
# report_q(self, state)
#     Report the current Q values for the given state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q (array of 3 floats):
#       reward plus expected future utility of each of the three actions.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# When your `q_learner` is first initialized, the value of $Q[state,action]$ should be zero for all state/action pairs, thus the `report_q` function should return lists of zeros:

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Q[0,0,0,0,0] is now:',q_learner.report_q([0,0,0,0,0]))
print('Q[9,9,1,1,9] is now:',q_learner.report_q([9,9,1,1,9]))
# Out:
# Q[0,0,0,0,0] is now: [0. 0. 0.]
# Q[9,9,1,1,9] is now: [0. 0. 0.]

# %% [markdown]
# There are actually many different Q-learning algorithms available, but when people refer to Q-learning with no modifier, they usually mean the time-difference (TD) algorithm.  For example, this is the algorithm that's described on the wikipedia page (https://en.wikipedia.org/wiki/Q-learning).  This is the algorithm you will implement for this MP.
#
# In supervised machine learning, the learner tries to imitate a reference label.  In reinforcement learning, there is no reference label.  Q-learning replaces the reference label with a "local Q" value, which is the utility that was obtained by performing action $a$ in state $s$ one time.  It is usually calculated like this:
#
# $$Q_{local}(s_t,a_t) = r_t + \gamma\max_{a_{t+1}}Q(s_{t+1},a_{t+1})$$
#
# where $r_t$ is the reward that was achieved by performing action $a_t$ in state $s_t$, $s_{t+1}$ is the state into which the game transitioned, and $a_{t+1}$ is one of the actions that could be performed in that state.  $Q_{local}$ is computed by your `q_local` function, which has this docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.q_local)
# Out:
# Help on function q_local in module submitted:
#
# q_local(self, reward, newstate)
#     The update to Q estimated from a single step of game play:
#     reward plus gamma times the max of Q[newstate, ...].
#
#     @param:
#     reward (scalar float): the reward achieved from the current step of game play.
#     newstate (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q_local (scalar float): the local value of Q

# %% [markdown]
# Initially, `q_local` should just return the given reward, because initially, all Q values are 0:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,10,10])
print('Q_local(6.25,[9,9,1,1,9]) is currently:',q_learner.q_local(6.25,[9,9,1,1,9]))
# Out:
# Q_local(6.25,[9,9,1,1,9]) is currently: 6.25

# %% [markdown]
# Now you can use `q_learner.q_local` as the target for `q_learner.learn`.  The basic algorithm is
#
# $$Q(s,a) = Q(s,a) + \alpha (Q_{local}(s,a)-Q(s,a))$$
#
# Here is the docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Update the internal Q-table on the basis of an observed
#     state, action, reward, newstate sequence.
#
#     @params:
#     state: a list of 5 numbers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle.
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 numbers, in the same format as state
#
#     @return:
#     None

# %% [markdown]
# The following block checks a sequence of Q updates:
#
# 1. First, $Q([9,9,1,1,9],-1)$ is updated.  Since all Q values start at zero, it will be updated to just have a value equal to $\alpha$ (0.05) times the given reward (6.25) for a total value of 0.3125.
# 1. When we print out $Q([9,9,1,1,9],:)$, we see that one of the elements has been updated.
# 1. Next, update $Q([9,9,1,1,8],1)$ with a given reward, and with $[9,9,1,1,9]$ as the given next state.  Since $Q([9,9,1,1,9],-1)$ is larger than zero, the next-state Q-value should be multiplied by $\gamma$ (0.99) and added to the reward (3.1), then multiplied by $\alpha$, giving a total value of 0.17046875.
# 1. The resulting Q-value is reported.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q[9,9,1,1,9] is now',q_learner.report_q([9,9,1,1,9]))
q_learner.learn([9,9,1,1,8],1,3.1,[9,9,1,1,9])
print('Q[9,9,1,1,8] is now',q_learner.report_q([9,9,1,1,8]))
# Out:
# Q[9,9,1,1,9] is now [0.3125 0.     0.    ]
# Q[9,9,1,1,8] is now [0.         0.         0.17046875]

# %% [markdown]
# <a id='section5'></a>

# %% [markdown]
# ## Saving and Loading your Q and N Tables

# %% [markdown]
# After you've spent a long time training your `q_learner`, you will want to save your Q and N tables so that you can reload them later.  The format of Q and N is up to you, therefore it's also up to you to write the `save` and `load` functions.  Here are the docstrings:

# %%
importlib.reload(submitted)
help(submitted.q_learner.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your Q and N tables to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.  We recommend numpy.savez,
#     but you can use something else if you prefer.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
importlib.reload(submitted)
help(submitted.q_learner.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load the Q and N tables from a file.
#     This should load from whatever file format your save function
#     used.  We recommend numpy.load, but you can use something
#     else if you prefer.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# These functions can be tested by doing one step of training one `q_learner`, then saving its results, then loading them into another `q_learner`:

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner1.choose_unexplored_action([9,9,1,1,9]))
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('N1[9,9,1,1,8] is now',q_learner1.report_exploration_counts([9,9,1,1,9]))
print('Q1[9,9,1,1,8] is now',q_learner1.report_q([9,9,1,1,9]))
q_learner1.save('test.npz')

q_learner2 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('N2[9,9,1,1,8] starts out as',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] starts out as',q_learner2.report_q([9,9,1,1,9]))
q_learner2.load('test.npz')
print('N2[9,9,1,1,8] is now',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] is now',q_learner2.report_q([9,9,1,1,9]))
# Out:
# Next action: 0
# N1[9,9,1,1,8] is now [0. 1. 0.]
# Q1[9,9,1,1,8] is now [0.3125 0.     0.    ]
# N2[9,9,1,1,8] starts out as [0. 0. 0.]
# Q2[9,9,1,1,8] starts out as [0. 0. 0.]
# N2[9,9,1,1,8] is now [0. 1. 0.]
# Q2[9,9,1,1,8] is now [0.3125 0.     0.    ]

# %% [markdown]
# <a id='section6'></a>

# %% [markdown]
# ## Exploitation

# %% [markdown]
# A reinforcement learner always has to trade off between exploration (choosing an action at random) versus exploitation (choosing the action with the maximum expected utility).  Before we worry about that tradeoff, though, let's first make sure that exploitation works.

# %%
importlib.reload(submitted)
help(submitted.q_learner.exploit)
# Out:
# Help on function exploit in module submitted:
#
# exploit(self, state)
#     Return the action that has the highest Q-value for the current state, and its Q-value.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar int): either -1, or 0, or 1.
#       The action that has the highest Q-value.  Ties can be broken any way you want.
#     Q (scalar float):
#       The Q-value of the selected action

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q1[9,9,1,1,9] is now',q_learner1.report_q([9,9,1,1,9]))
print('The best action and Q from state [9,9,1,1,9] are',q_learner1.exploit([9,9,1,1,9]))
# Out:
# Q1[9,9,1,1,9] is now [0.3125 0.     0.    ]
# The best action and Q from state [9,9,1,1,9] are (-1, 0.3125)

# %% [markdown]
# <a id='section7'></a>

# %% [markdown]
# ## Acting

# %% [markdown]
# When your learner decides which action to perform, it should trade off exploration vs. exploitation using both the epsilon-first and the epsilon-greedy strategies:
# 1. If there is any action that has been explored fewer than `nfirst` times, then choose one of those actions at random.  Otherwise...
# 1. With probability `epsilon`, choose an action at random.  Otherwise...
# 1. Exploit.

# %%
importlib.reload(submitted)
help(submitted.q_learner.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     If any action has been taken less than nfirst times, then choose one of those
#     actions, uniformly at random.
#     Otherwise, with probability epsilon, choose an action uniformly at random.
#     Otherwise, choose the action with the best Q(state,action).
#
#     @params:
#     state: a list of 5 integers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %% [markdown]
# In order to test all three types of action (epsilon-first exploration, epsilon-greedy exploration, and exploitation), let's create a learner with `nfirst=1` and `epsilon=0.25`, and set it so that the best action from state `[9,9,1,1,9]` is `-1`.  With these settings, a sequence of calls to `q_learner.act` should produce the following sequence of actions:
#
# 1. The first three actions should include each possible action once.
# 1. After the first three actions, 3/4 of the remaining actions should be `-1`.  The remaining 1/4 should be randomly chosen.

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.25,0.99,1,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
# Out:
# An epsilon-first action: -1
# An epsilon-first action: 0
# An epsilon-first action: 1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1

# %% [markdown]
# <a id='section8'></a>

# %% [markdown]
# ## Training

# %% [markdown]
# Now that all of your components work, you can try training your algorithm.  Do this by giving your `q_learner` as a player to a new `pong.PongGame` object.  Set `visibility=False` so that the `PongGame` doesn't create a new window.

# %%
import pong, importlib, submitted
importlib.reload(pong)
help(pong.PongGame.__init__)
# Out:
# Help on function __init__ in module pong:
#
# __init__(self, ball_speed=4, paddle_speed=8, learner=None, visible=True, state_quantization=[10, 10, 2, 2, 10])
#     Create a new pong game, with a specified player.
#
#     @params:
#     ball_speed (scalar int) - average ball speed in pixels/frame
#     paddle_speed (scalar int) - paddle moves 0, +paddle_speed, or -paddle_speed
#     learner - can be None if the player is human.  If not None, should be an
#       object of type random_learner, submitted.q_learner, or submitted.deep_q.
#     visible (bool) - should this game have an attached pygame window?
#     state_quantization (list) - if not None, state variables are quantized
#       into integers of these cardinalities before being passed to the learner.

# %% [markdown]
# As you can see, we should set `visibility=False` so that the `PongGame` doesn't create a new window.  We should also make sure that the PongGame uses the same state quantization as the learner.

# %%
importlib.reload(pong)
importlib.reload(submitted)
state_quantization = [10,10,2,2,10]
q_learner=submitted.q_learner(0.05,0.05,0.99,5,state_quantization)

pong_game = pong.PongGame(learner=q_learner, visible=False, state_quantization=state_quantization)
print(pong_game)
# Out:
# <pong.PongGame object at 0x29c5372b0>

# %% [markdown]
# In order to train our learner, we want it to play the game many times.  To do that we use the PongGame.run function:

# %%
help(pong_game.run)
# Out:
# Help on method run in module pong:
#
# run(m_rewards=inf, m_games=inf, m_frames=inf, states=[]) method of pong.PongGame instance
#     Run the game.
#     @param
#     m_frames (scalar int): maximum number of frames to be played
#     m_rewards (scalar int): maximum number of rewards earned (+ or -)
#     m_games (scalar int): maximum number of games
#     states (list): list of states whose Q-values should be returned
#        each state is a list of 5 ints: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#        and the y-position of the paddle, all quantized.
#        0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#
#     @return
#     scores (list): list of scores of all completed games
#
#     The following will be returned only if the player is q_learning or deep_q.
#     New elements will be added to these lists once/frame if m_frames is specified,
#     else once/reward if m_rewards is specified, else once/game:
#       q_achieved (list): list of the q-values of the moves that were taken
#       q_states (list): list of the q-values of requested states

# %% [markdown]
# In order to make sure our learner is learning, let's tell `pong_game.run` to output all 3 Q-values of all of the 4000 states in every time step.
#
# To make sure that's not an outrageous amount of data, let's tell it to only output the Q values once/reward, and ask it to only collect 5000 rewards:

# %%
states = [[x,y,vx,vy,py] for x in range(10) for y in range(10) for vx in range(2) for vy in range(2) for py in range(10) ]

scores, q_achieved, q_states = pong_game.run(m_rewards=500, states=states)

print('The number of games played was',len(scores))
print('The number of rewards was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 2 rewards, 552 frames, score 1, max score 8
# Completed 1 games, 5 rewards, 1106 frames, score 2, max score 8
# Completed 2 games, 6 rewards, 1360 frames, score 0, max score 8
# Completed 3 games, 9 rewards, 1989 frames, score 2, max score 8
# Completed 4 games, 15 rewards, 3020 frames, score 5, max score 8
# Completed 5 games, 17 rewards, 3403 frames, score 1, max score 8
# Completed 6 games, 21 rewards, 4057 frames, score 3, max score 8
# Completed 7 games, 24 rewards, 4627 frames, score 2, max score 8
# Completed 8 games, 25 rewards, 4808 frames, score 0, max score 8
# Completed 9 games, 30 rewards, 5564 frames, score 4, max score 8
# Completed 10 games, 34 rewards, 6829 frames, score 3, max score 8
# Completed 11 games, 36 rewards, 7269 frames, score 1, max score 8
# Completed 12 games, 37 rewards, 7450 frames, score 0, max score 8
# Completed 13 games, 38 rewards, 7631 frames, score 0, max score 8
# Completed 14 games, 39 rewards, 7812 frames, score 0, max score 8
# Completed 15 games, 44 rewards, 8863 frames, score 4, max score 8
# Completed 16 games, 46 rewards, 9525 frames, score 1, max score 8
# Completed 17 games, 47 rewards, 9779 frames, score 0, max score 8
# Completed 18 games, 49 rewards, 10184 frames, score 1, max score 8
# Completed 19 games, 51 rewards, 10918 frames, score 1, max score 8
# Completed 20 games, 53 rewards, 11452 frames, score 1, max score 8
# Completed 21 games, 54 rewards, 11660 frames, score 0, max score 8
# Completed 22 games, 58 rewards, 12335 frames, score 3, max score 8
# Completed 23 games, 61 rewards, 13008 frames, score 2, max score 8
# Completed 24 games, 66 rewards, 13931 frames, score 4, max score 8
# Completed 25 games, 67 rewards, 14112 frames, score 0, max score 8
# Completed 26 games, 68 rewards, 14366 frames, score 0, max score 8
# Completed 27 games, 72 rewards, 15315 frames, score 3, max score 8
# Completed 28 games, 78 rewards, 16485 frames, score 5, max score 8
# Completed 29 games, 80 rewards, 17147 frames, score 1, max score 8
# Completed 30 games, 82 rewards, 18066 frames, score 1, max score 8
# Completed 31 games, 83 rewards, 18274 frames, score 0, max score 8
# Completed 32 games, 85 rewards, 18874 frames, score 1, max score 8
# Completed 33 games, 87 rewards, 19425 frames, score 1, max score 8
# Completed 34 games, 88 rewards, 19606 frames, score 0, max score 8
# Completed 35 games, 90 rewards, 20479 frames, score 1, max score 8
# Completed 36 games, 91 rewards, 20687 frames, score 0, max score 8
# Completed 37 games, 97 rewards, 22330 frames, score 5, max score 8
# Completed 38 games, 99 rewards, 22881 frames, score 1, max score 8
# Completed 39 games, 100 rewards, 23062 frames, score 0, max score 8
# Completed 40 games, 102 rewards, 23467 frames, score 1, max score 8
# Completed 41 games, 103 rewards, 23648 frames, score 0, max score 8
# Completed 42 games, 105 rewards, 24382 frames, score 1, max score 8
# Completed 43 games, 106 rewards, 24636 frames, score 0, max score 8
# Completed 44 games, 107 rewards, 24817 frames, score 0, max score 8
# Completed 45 games, 111 rewards, 25678 frames, score 3, max score 8
# Completed 46 games, 113 rewards, 26054 frames, score 1, max score 8
# Completed 47 games, 114 rewards, 26235 frames, score 0, max score 8
# Completed 48 games, 115 rewards, 26443 frames, score 0, max score 8
# Completed 49 games, 124 rewards, 28843 frames, score 8, max score 8
# Completed 50 games, 126 rewards, 29241 frames, score 1, max score 8
# Completed 51 games, 127 rewards, 29495 frames, score 0, max score 8
# Completed 52 games, 131 rewards, 31898 frames, score 3, max score 8
# Completed 53 games, 133 rewards, 32303 frames, score 1, max score 8
# Completed 54 games, 136 rewards, 32842 frames, score 2, max score 8
# Completed 55 games, 137 rewards, 33023 frames, score 0, max score 8
# Completed 56 games, 138 rewards, 33231 frames, score 0, max score 8
# Completed 57 games, 139 rewards, 33412 frames, score 0, max score 8
# Completed 58 games, 141 rewards, 33900 frames, score 1, max score 8
# Completed 59 games, 142 rewards, 34081 frames, score 0, max score 8
# Completed 60 games, 145 rewards, 34933 frames, score 2, max score 8
# Completed 61 games, 146 rewards, 35187 frames, score 0, max score 8
# Completed 62 games, 147 rewards, 35395 frames, score 0, max score 8
# Completed 63 games, 149 rewards, 36057 frames, score 1, max score 8
# Completed 64 games, 150 rewards, 36238 frames, score 0, max score 8
# Completed 65 games, 154 rewards, 37056 frames, score 3, max score 8
# Completed 66 games, 155 rewards, 37264 frames, score 0, max score 8
# Completed 67 games, 156 rewards, 37518 frames, score 0, max score 8
# Completed 68 games, 157 rewards, 37699 frames, score 0, max score 8
# Completed 69 games, 158 rewards, 37880 frames, score 0, max score 8
# Completed 70 games, 161 rewards, 38510 frames, score 2, max score 8
# Completed 71 games, 162 rewards, 38718 frames, score 0, max score 8
# Completed 72 games, 164 rewards, 39218 frames, score 1, max score 8
# Completed 73 games, 165 rewards, 39426 frames, score 0, max score 8
# Completed 74 games, 168 rewards, 40125 frames, score 2, max score 8
# Completed 75 games, 172 rewards, 40968 frames, score 3, max score 8
# Completed 76 games, 174 rewards, 41465 frames, score 1, max score 8
# Completed 77 games, 175 rewards, 41719 frames, score 0, max score 8
# Completed 78 games, 177 rewards, 42132 frames, score 1, max score 8
# Completed 79 games, 178 rewards, 42340 frames, score 0, max score 8
# Completed 80 games, 184 rewards, 43402 frames, score 5, max score 8
# Completed 81 games, 185 rewards, 43656 frames, score 0, max score 8
# Completed 82 games, 186 rewards, 43837 frames, score 0, max score 8
# Completed 83 games, 190 rewards, 44546 frames, score 3, max score 8
# Completed 84 games, 192 rewards, 45006 frames, score 1, max score 8
# Completed 85 games, 193 rewards, 45214 frames, score 0, max score 8
# Completed 86 games, 196 rewards, 47238 frames, score 2, max score 8
# Completed 87 games, 201 rewards, 48249 frames, score 4, max score 8
# Completed 88 games, 203 rewards, 48601 frames, score 1, max score 8
# Completed 89 games, 205 rewards, 49263 frames, score 1, max score 8
# Completed 90 games, 210 rewards, 50055 frames, score 4, max score 8
# Completed 91 games, 215 rewards, 50964 frames, score 4, max score 8
# Completed 92 games, 216 rewards, 51172 frames, score 0, max score 8
# Completed 93 games, 217 rewards, 51353 frames, score 0, max score 8
# Completed 94 games, 220 rewards, 53141 frames, score 2, max score 8
# Completed 95 games, 221 rewards, 53322 frames, score 0, max score 8
# Completed 96 games, 222 rewards, 53576 frames, score 0, max score 8
# Completed 97 games, 223 rewards, 53757 frames, score 0, max score 8
# Completed 98 games, 224 rewards, 53965 frames, score 0, max score 8
# Completed 99 games, 225 rewards, 54219 frames, score 0, max score 8
# Completed 100 games, 228 rewards, 54773 frames, score 2, max score 8
# Completed 101 games, 233 rewards, 55802 frames, score 4, max score 8
# Completed 102 games, 234 rewards, 56010 frames, score 0, max score 8
# Completed 103 games, 237 rewards, 56963 frames, score 2, max score 8
# Completed 104 games, 238 rewards, 57171 frames, score 0, max score 8
# Completed 105 games, 240 rewards, 57512 frames, score 1, max score 8
# Completed 106 games, 242 rewards, 57983 frames, score 1, max score 8
# Completed 107 games, 245 rewards, 58879 frames, score 2, max score 8
# Completed 108 games, 247 rewards, 59413 frames, score 1, max score 8
# Completed 109 games, 248 rewards, 59621 frames, score 0, max score 8
# Completed 110 games, 249 rewards, 59875 frames, score 0, max score 8
# Completed 111 games, 251 rewards, 60303 frames, score 1, max score 8
# Completed 112 games, 254 rewards, 60828 frames, score 2, max score 8
# Completed 113 games, 255 rewards, 61082 frames, score 0, max score 8
# Completed 114 games, 258 rewards, 61617 frames, score 2, max score 8
# Completed 115 games, 260 rewards, 62054 frames, score 1, max score 8
# Completed 116 games, 262 rewards, 62482 frames, score 1, max score 8
# Completed 117 games, 263 rewards, 62736 frames, score 0, max score 8
# Completed 118 games, 265 rewards, 63141 frames, score 1, max score 8
# Completed 119 games, 266 rewards, 63395 frames, score 0, max score 8
# Completed 120 games, 267 rewards, 63576 frames, score 0, max score 8
# Completed 121 games, 271 rewards, 64435 frames, score 3, max score 8
# Completed 122 games, 273 rewards, 64898 frames, score 1, max score 8
# Completed 123 games, 274 rewards, 65079 frames, score 0, max score 8
# Completed 124 games, 277 rewards, 65871 frames, score 2, max score 8
# Completed 125 games, 279 rewards, 66383 frames, score 1, max score 8
# Completed 126 games, 284 rewards, 67412 frames, score 4, max score 8
# Completed 127 games, 285 rewards, 67620 frames, score 0, max score 8
# Completed 128 games, 286 rewards, 67801 frames, score 0, max score 8
# Completed 129 games, 293 rewards, 69628 frames, score 6, max score 8
# Completed 130 games, 294 rewards, 69809 frames, score 0, max score 8
# Completed 131 games, 295 rewards, 69990 frames, score 0, max score 8
# Completed 132 games, 296 rewards, 70244 frames, score 0, max score 8
# Completed 133 games, 297 rewards, 70452 frames, score 0, max score 8
# Completed 134 games, 300 rewards, 70942 frames, score 2, max score 8
# Completed 135 games, 301 rewards, 71123 frames, score 0, max score 8
# Completed 136 games, 303 rewards, 71586 frames, score 1, max score 8
# Completed 137 games, 305 rewards, 72120 frames, score 1, max score 8
# Completed 138 games, 306 rewards, 72328 frames, score 0, max score 8
# Completed 139 games, 307 rewards, 72582 frames, score 0, max score 8
# Completed 140 games, 308 rewards, 72790 frames, score 0, max score 8
# Completed 141 games, 309 rewards, 73044 frames, score 0, max score 8
# Completed 142 games, 310 rewards, 73225 frames, score 0, max score 8
# Completed 143 games, 311 rewards, 73479 frames, score 0, max score 8
# Completed 144 games, 315 rewards, 74474 frames, score 3, max score 8
# Completed 145 games, 316 rewards, 74682 frames, score 0, max score 8
# Completed 146 games, 318 rewards, 75142 frames, score 1, max score 8
# Completed 147 games, 319 rewards, 75350 frames, score 0, max score 8
# Completed 148 games, 320 rewards, 75558 frames, score 0, max score 8
# Completed 149 games, 322 rewards, 75899 frames, score 1, max score 8
# Completed 150 games, 324 rewards, 76633 frames, score 1, max score 8
# Completed 151 games, 327 rewards, 77241 frames, score 2, max score 8
# Completed 152 games, 329 rewards, 77609 frames, score 1, max score 8
# Completed 153 games, 332 rewards, 78336 frames, score 2, max score 8
# Completed 154 games, 333 rewards, 78544 frames, score 0, max score 8
# Completed 155 games, 334 rewards, 78798 frames, score 0, max score 8
# Completed 156 games, 335 rewards, 79052 frames, score 0, max score 8
# Completed 157 games, 338 rewards, 79876 frames, score 2, max score 8
# Completed 158 games, 340 rewards, 80281 frames, score 1, max score 8
# Completed 159 games, 342 rewards, 80687 frames, score 1, max score 8
# Completed 160 games, 343 rewards, 80895 frames, score 0, max score 8
# Completed 161 games, 346 rewards, 82542 frames, score 2, max score 8
# Completed 162 games, 348 rewards, 82979 frames, score 1, max score 8
# Completed 163 games, 349 rewards, 83233 frames, score 0, max score 8
# Completed 164 games, 350 rewards, 83441 frames, score 0, max score 8
# Completed 165 games, 351 rewards, 83649 frames, score 0, max score 8
# Completed 166 games, 352 rewards, 83857 frames, score 0, max score 8
# Completed 167 games, 356 rewards, 84800 frames, score 3, max score 8
# Completed 168 games, 364 rewards, 86147 frames, score 7, max score 8
# Completed 169 games, 366 rewards, 86499 frames, score 1, max score 8
# Completed 170 games, 367 rewards, 86680 frames, score 0, max score 8
# Completed 171 games, 369 rewards, 87032 frames, score 1, max score 8
# Completed 172 games, 371 rewards, 87544 frames, score 1, max score 8
# Completed 173 games, 372 rewards, 87798 frames, score 0, max score 8
# Completed 174 games, 375 rewards, 88752 frames, score 2, max score 8
# Completed 175 games, 376 rewards, 89006 frames, score 0, max score 8
# Completed 176 games, 379 rewards, 89541 frames, score 2, max score 8
# Completed 177 games, 380 rewards, 89749 frames, score 0, max score 8
# Completed 178 games, 382 rewards, 90351 frames, score 1, max score 8
# Completed 179 games, 383 rewards, 90532 frames, score 0, max score 8
# Completed 180 games, 384 rewards, 90740 frames, score 0, max score 8
# Completed 181 games, 386 rewards, 91660 frames, score 1, max score 8
# Completed 182 games, 387 rewards, 91868 frames, score 0, max score 8
# Completed 183 games, 388 rewards, 92076 frames, score 0, max score 8
# Completed 184 games, 389 rewards, 92330 frames, score 0, max score 8
# Completed 185 games, 397 rewards, 93707 frames, score 7, max score 8
# Completed 186 games, 398 rewards, 93888 frames, score 0, max score 8
# Completed 187 games, 400 rewards, 94256 frames, score 1, max score 8
# Completed 188 games, 402 rewards, 94693 frames, score 1, max score 8
# Completed 189 games, 404 rewards, 95149 frames, score 1, max score 8
# Completed 190 games, 406 rewards, 95554 frames, score 1, max score 8
# Completed 191 games, 407 rewards, 95808 frames, score 0, max score 8
# Completed 192 games, 411 rewards, 96845 frames, score 3, max score 8
# Completed 193 games, 414 rewards, 97460 frames, score 2, max score 8
# Completed 194 games, 415 rewards, 97668 frames, score 0, max score 8
# Completed 195 games, 416 rewards, 97922 frames, score 0, max score 8
# Completed 196 games, 417 rewards, 98103 frames, score 0, max score 8
# Completed 197 games, 418 rewards, 98311 frames, score 0, max score 8
# Completed 198 games, 421 rewards, 99196 frames, score 2, max score 8
# Completed 199 games, 422 rewards, 99377 frames, score 0, max score 8
# Completed 200 games, 424 rewards, 99921 frames, score 1, max score 8
# Completed 201 games, 426 rewards, 100384 frames, score 1, max score 8
# Completed 202 games, 430 rewards, 101140 frames, score 3, max score 8
# Completed 203 games, 431 rewards, 101321 frames, score 0, max score 8
# Completed 204 games, 434 rewards, 101818 frames, score 2, max score 8
# Completed 205 games, 437 rewards, 102772 frames, score 2, max score 8
# Completed 206 games, 439 rewards, 103178 frames, score 1, max score 8
# Completed 207 games, 441 rewards, 103675 frames, score 1, max score 8
# Completed 208 games, 442 rewards, 103883 frames, score 0, max score 8
# Completed 209 games, 443 rewards, 104137 frames, score 0, max score 8
# Completed 210 games, 450 rewards, 105471 frames, score 6, max score 8
# Completed 211 games, 452 rewards, 106159 frames, score 1, max score 8
# Completed 212 games, 454 rewards, 106566 frames, score 1, max score 8
# Completed 213 games, 455 rewards, 106820 frames, score 0, max score 8
# Completed 214 games, 456 rewards, 107074 frames, score 0, max score 8
# Completed 215 games, 457 rewards, 107282 frames, score 0, max score 8
# Completed 216 games, 459 rewards, 107761 frames, score 1, max score 8
# Completed 217 games, 460 rewards, 107942 frames, score 0, max score 8
# Completed 218 games, 462 rewards, 108310 frames, score 1, max score 8
# Completed 219 games, 463 rewards, 108564 frames, score 0, max score 8
# Completed 220 games, 465 rewards, 109024 frames, score 1, max score 8
# Completed 221 games, 466 rewards, 109232 frames, score 0, max score 8
# Completed 222 games, 467 rewards, 109486 frames, score 0, max score 8
# Completed 223 games, 470 rewards, 110090 frames, score 2, max score 8
# Completed 224 games, 474 rewards, 110953 frames, score 3, max score 8
# Completed 225 games, 476 rewards, 111441 frames, score 1, max score 8
# Completed 226 games, 480 rewards, 112163 frames, score 3, max score 8
# Completed 227 games, 481 rewards, 112417 frames, score 0, max score 8
# Completed 228 games, 484 rewards, 113030 frames, score 2, max score 8
# Completed 229 games, 485 rewards, 113238 frames, score 0, max score 8
# Completed 230 games, 486 rewards, 113419 frames, score 0, max score 8
# Completed 231 games, 488 rewards, 113970 frames, score 1, max score 8
# Completed 232 games, 492 rewards, 114766 frames, score 3, max score 8
# Completed 233 games, 493 rewards, 114947 frames, score 0, max score 8
# Completed 234 games, 495 rewards, 115455 frames, score 1, max score 8
# Completed 235 games, 500 rewards, 117470 frames, score 4, max score 8
# The number of games played was 237
# The number of rewards was 500
# The size of each returned Q-matrix was (4000, 3)

# %% [markdown]
# The returned value of `q_states` is a list of 4000x3 numpy arrays (20 states, 3 actions).  The list contains `m_rewards` of these. We want to convert it into something that matplotlib can plot.

# %%
import numpy as np

Q = np.array([np.reshape(q,-1) for q in q_states])
print('Q is now of shape',Q.shape)
print('the max absolute value of Q is ',np.amax(abs(Q)))
# Out:
# Q is now of shape (500, 12000)
# the max absolute value of Q is  2.593432580780317

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,6),layout='tight')
ax = [ fig.add_subplot(2,1,x) for x in range(1,3) ]
ax[0].plot(np.arange(0,len(q_states)),Q)
ax[0].set_title('Q values of all states')
ax[1].plot(np.arange(0,len(q_states)),q_achieved)
ax[1].set_title('Q values of state achieved at each time')
ax[1].set_ylabel('Reward number')
# Out:
# Text(0, 0.5, 'Reward number')

# %% [markdown]
# OK, now let's try running it for a much longer period -- say, 5000 complete games.  We won't ask it to print out any states this time.

# %%
scores, q_achieved, q_states = pong_game.run(m_games=5000, states=[])

print('The number of games played was',len(scores))
print('The number of video frames was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 2 rewards, 399 frames, score 1, max score 8
# Completed 1 games, 5 rewards, 1046 frames, score 2, max score 8
# Completed 2 games, 6 rewards, 1300 frames, score 0, max score 8
# Completed 3 games, 7 rewards, 1508 frames, score 0, max score 8
# Completed 4 games, 8 rewards, 1716 frames, score 0, max score 8
# Completed 5 games, 9 rewards, 1970 frames, score 0, max score 8
# Completed 6 games, 10 rewards, 2178 frames, score 0, max score 8
# Completed 7 games, 13 rewards, 2684 frames, score 2, max score 8
# Completed 8 games, 14 rewards, 2865 frames, score 0, max score 8
# Completed 9 games, 15 rewards, 3119 frames, score 0, max score 8
# Completed 10 games, 16 rewards, 3373 frames, score 0, max score 8
# Completed 11 games, 17 rewards, 3627 frames, score 0, max score 8
# Completed 12 games, 23 rewards, 6337 frames, score 5, max score 8
# Completed 13 games, 25 rewards, 6702 frames, score 1, max score 8
# Completed 14 games, 27 rewards, 7165 frames, score 1, max score 8
# Completed 15 games, 28 rewards, 7346 frames, score 0, max score 8
# Completed 16 games, 29 rewards, 7554 frames, score 0, max score 8
# Completed 17 games, 32 rewards, 8169 frames, score 2, max score 8
# Completed 18 games, 34 rewards, 8536 frames, score 1, max score 8
# Completed 19 games, 36 rewards, 8941 frames, score 1, max score 8
# Completed 20 games, 39 rewards, 10183 frames, score 2, max score 8
# Completed 21 games, 40 rewards, 10437 frames, score 0, max score 8
# Completed 22 games, 41 rewards, 10691 frames, score 0, max score 8
# Completed 23 games, 42 rewards, 10872 frames, score 0, max score 8
# Completed 24 games, 44 rewards, 11240 frames, score 1, max score 8
# Completed 25 games, 49 rewards, 13835 frames, score 4, max score 8
# Completed 26 games, 56 rewards, 16703 frames, score 6, max score 8
# Completed 27 games, 61 rewards, 17519 frames, score 4, max score 8
# Completed 28 games, 65 rewards, 18111 frames, score 3, max score 8
# Completed 29 games, 66 rewards, 18365 frames, score 0, max score 8
# Completed 30 games, 67 rewards, 18619 frames, score 0, max score 8
# Completed 31 games, 71 rewards, 19502 frames, score 3, max score 8
# Completed 32 games, 73 rewards, 19965 frames, score 1, max score 8
# Completed 33 games, 76 rewards, 20471 frames, score 2, max score 8
# Completed 34 games, 77 rewards, 20652 frames, score 0, max score 8
# Completed 35 games, 79 rewards, 21030 frames, score 1, max score 8
# Completed 36 games, 81 rewards, 21518 frames, score 1, max score 8
# Completed 37 games, 83 rewards, 22007 frames, score 1, max score 8
# Completed 38 games, 85 rewards, 22461 frames, score 1, max score 8
# Completed 39 games, 88 rewards, 23090 frames, score 2, max score 8
# Completed 40 games, 91 rewards, 23933 frames, score 2, max score 8
# Completed 41 games, 92 rewards, 24141 frames, score 0, max score 8
# Completed 42 games, 101 rewards, 25574 frames, score 8, max score 8
# Completed 43 games, 102 rewards, 25755 frames, score 0, max score 8
# Completed 44 games, 104 rewards, 26252 frames, score 1, max score 8
# Completed 45 games, 107 rewards, 26797 frames, score 2, max score 8
# Completed 46 games, 112 rewards, 27726 frames, score 4, max score 8
# Completed 47 games, 114 rewards, 28223 frames, score 1, max score 8
# Completed 48 games, 116 rewards, 28651 frames, score 1, max score 8
# Completed 49 games, 121 rewards, 29891 frames, score 4, max score 8
# Completed 50 games, 122 rewards, 30072 frames, score 0, max score 8
# Completed 51 games, 125 rewards, 31202 frames, score 2, max score 8
# Completed 52 games, 129 rewards, 32208 frames, score 3, max score 8
# Completed 53 games, 133 rewards, 33017 frames, score 3, max score 8
# Completed 54 games, 134 rewards, 33225 frames, score 0, max score 8
# Completed 55 games, 135 rewards, 33406 frames, score 0, max score 8
# Completed 56 games, 137 rewards, 33811 frames, score 1, max score 8
# Completed 57 games, 140 rewards, 34624 frames, score 2, max score 8
# Completed 58 games, 141 rewards, 34832 frames, score 0, max score 8
# Completed 59 games, 143 rewards, 35383 frames, score 1, max score 8
# Completed 60 games, 148 rewards, 36323 frames, score 4, max score 8
# Completed 61 games, 152 rewards, 37143 frames, score 3, max score 8
# Completed 62 games, 154 rewards, 37631 frames, score 1, max score 8
# Completed 63 games, 157 rewards, 38538 frames, score 2, max score 8
# Completed 64 games, 158 rewards, 38746 frames, score 0, max score 8
# Completed 65 games, 164 rewards, 39723 frames, score 5, max score 8
# Completed 66 games, 168 rewards, 40709 frames, score 3, max score 8
# Completed 67 games, 169 rewards, 40890 frames, score 0, max score 8
# Completed 68 games, 173 rewards, 41800 frames, score 3, max score 8
# Completed 69 games, 174 rewards, 42054 frames, score 0, max score 8
# Completed 70 games, 175 rewards, 42262 frames, score 0, max score 8
# Completed 71 games, 177 rewards, 42614 frames, score 1, max score 8
# Completed 72 games, 181 rewards, 43236 frames, score 3, max score 8
# Completed 73 games, 184 rewards, 43877 frames, score 2, max score 8
# Completed 74 games, 190 rewards, 44969 frames, score 5, max score 8
# Completed 75 games, 191 rewards, 45150 frames, score 0, max score 8
# Completed 76 games, 193 rewards, 45621 frames, score 1, max score 8
# Completed 77 games, 195 rewards, 46049 frames, score 1, max score 8
# Completed 78 games, 198 rewards, 46714 frames, score 2, max score 8
# Completed 79 games, 201 rewards, 47465 frames, score 2, max score 8
# Completed 80 games, 202 rewards, 47719 frames, score 0, max score 8
# Completed 81 games, 203 rewards, 47900 frames, score 0, max score 8
# Completed 82 games, 204 rewards, 48081 frames, score 0, max score 8
# Completed 83 games, 206 rewards, 48518 frames, score 1, max score 8
# Completed 84 games, 207 rewards, 48699 frames, score 0, max score 8
# Completed 85 games, 210 rewards, 49364 frames, score 2, max score 8
# Completed 86 games, 212 rewards, 49705 frames, score 1, max score 8
# Completed 87 games, 215 rewards, 50290 frames, score 2, max score 8
# Completed 88 games, 220 rewards, 51499 frames, score 4, max score 8
# Completed 89 games, 221 rewards, 51680 frames, score 0, max score 8
# Completed 90 games, 222 rewards, 51861 frames, score 0, max score 8
# Completed 91 games, 226 rewards, 52559 frames, score 3, max score 8
# Completed 92 games, 228 rewards, 53479 frames, score 1, max score 8
# Completed 93 games, 230 rewards, 53862 frames, score 1, max score 8
# Completed 94 games, 233 rewards, 54495 frames, score 2, max score 8
# Completed 95 games, 235 rewards, 54847 frames, score 1, max score 8
# Completed 96 games, 241 rewards, 55943 frames, score 5, max score 8
# Completed 97 games, 245 rewards, 56886 frames, score 3, max score 8
# Completed 98 games, 250 rewards, 57972 frames, score 4, max score 8
# Completed 99 games, 251 rewards, 58226 frames, score 0, max score 8
# Completed 100 games, 252 rewards, 58407 frames, score 0, max score 8
# Completed 101 games, 254 rewards, 58958 frames, score 1, max score 8
# Completed 102 games, 255 rewards, 59166 frames, score 0, max score 8
# Completed 103 games, 256 rewards, 59347 frames, score 0, max score 8
# Completed 104 games, 258 rewards, 59949 frames, score 1, max score 8
# Completed 105 games, 259 rewards, 60203 frames, score 0, max score 8
# Completed 106 games, 260 rewards, 60457 frames, score 0, max score 8
# Completed 107 games, 262 rewards, 61119 frames, score 1, max score 8
# Completed 108 games, 265 rewards, 61766 frames, score 2, max score 8
# Completed 109 games, 267 rewards, 62244 frames, score 1, max score 8
# Completed 110 games, 268 rewards, 62452 frames, score 0, max score 8
# Completed 111 games, 274 rewards, 63751 frames, score 5, max score 8
# Completed 112 games, 277 rewards, 64861 frames, score 2, max score 8
# Completed 113 games, 287 rewards, 66680 frames, score 9, max score 9
# Completed 114 games, 288 rewards, 66888 frames, score 0, max score 9
# Completed 115 games, 291 rewards, 68391 frames, score 2, max score 9
# Completed 116 games, 295 rewards, 70064 frames, score 3, max score 9
# Completed 117 games, 298 rewards, 70641 frames, score 2, max score 9
# Completed 118 games, 300 rewards, 71055 frames, score 1, max score 9
# Completed 119 games, 305 rewards, 71901 frames, score 4, max score 9
# Completed 120 games, 307 rewards, 72491 frames, score 1, max score 9
# Completed 121 games, 308 rewards, 72699 frames, score 0, max score 9
# Completed 122 games, 311 rewards, 73253 frames, score 2, max score 9
# Completed 123 games, 312 rewards, 73434 frames, score 0, max score 9
# Completed 124 games, 315 rewards, 73959 frames, score 2, max score 9
# Completed 125 games, 318 rewards, 74783 frames, score 2, max score 9
# Completed 126 games, 326 rewards, 80186 frames, score 7, max score 9
# Completed 127 games, 331 rewards, 81386 frames, score 4, max score 9
# Completed 128 games, 334 rewards, 82137 frames, score 2, max score 9
# Completed 129 games, 335 rewards, 82345 frames, score 0, max score 9
# Completed 130 games, 337 rewards, 82782 frames, score 1, max score 9
# Completed 131 games, 339 rewards, 83195 frames, score 1, max score 9
# Completed 132 games, 340 rewards, 83449 frames, score 0, max score 9
# Completed 133 games, 342 rewards, 83854 frames, score 1, max score 9
# Completed 134 games, 344 rewards, 84325 frames, score 1, max score 9
# Completed 135 games, 345 rewards, 84506 frames, score 0, max score 9
# Completed 136 games, 346 rewards, 84714 frames, score 0, max score 9
# Completed 137 games, 348 rewards, 85055 frames, score 1, max score 9
# Completed 138 games, 349 rewards, 85236 frames, score 0, max score 9
# Completed 139 games, 352 rewards, 86200 frames, score 2, max score 9
# Completed 140 games, 354 rewards, 86598 frames, score 1, max score 9
# Completed 141 games, 358 rewards, 87510 frames, score 3, max score 9
# Completed 142 games, 361 rewards, 88202 frames, score 2, max score 9
# Completed 143 games, 362 rewards, 88456 frames, score 0, max score 9
# Completed 144 games, 363 rewards, 88710 frames, score 0, max score 9
# Completed 145 games, 365 rewards, 89108 frames, score 1, max score 9
# Completed 146 games, 367 rewards, 89513 frames, score 1, max score 9
# Completed 147 games, 369 rewards, 89865 frames, score 1, max score 9
# Completed 148 games, 371 rewards, 90599 frames, score 1, max score 9
# Completed 149 games, 374 rewards, 91105 frames, score 2, max score 9
# Completed 150 games, 375 rewards, 91359 frames, score 0, max score 9
# Completed 151 games, 378 rewards, 91896 frames, score 2, max score 9
# Completed 152 games, 380 rewards, 92393 frames, score 1, max score 9
# Completed 153 games, 382 rewards, 92784 frames, score 1, max score 9
# Completed 154 games, 387 rewards, 94408 frames, score 4, max score 9
# Completed 155 games, 388 rewards, 94616 frames, score 0, max score 9
# Completed 156 games, 390 rewards, 95070 frames, score 1, max score 9
# Completed 157 games, 393 rewards, 95872 frames, score 2, max score 9
# Completed 158 games, 394 rewards, 96126 frames, score 0, max score 9
# Completed 159 games, 395 rewards, 96307 frames, score 0, max score 9
# Completed 160 games, 399 rewards, 97159 frames, score 3, max score 9
# Completed 161 games, 400 rewards, 97413 frames, score 0, max score 9
# Completed 162 games, 404 rewards, 98215 frames, score 3, max score 9
# Completed 163 games, 408 rewards, 100012 frames, score 3, max score 9
# Completed 164 games, 410 rewards, 100475 frames, score 1, max score 9
# Completed 165 games, 411 rewards, 100729 frames, score 0, max score 9
# Completed 166 games, 413 rewards, 101208 frames, score 1, max score 9
# Completed 167 games, 414 rewards, 101462 frames, score 0, max score 9
# Completed 168 games, 418 rewards, 103730 frames, score 3, max score 9
# Completed 169 games, 421 rewards, 104539 frames, score 2, max score 9
# Completed 170 games, 422 rewards, 104747 frames, score 0, max score 9
# Completed 171 games, 424 rewards, 105175 frames, score 1, max score 9
# Completed 172 games, 431 rewards, 106319 frames, score 6, max score 9
# Completed 173 games, 434 rewards, 107121 frames, score 2, max score 9
# Completed 174 games, 437 rewards, 108979 frames, score 2, max score 9
# Completed 175 games, 439 rewards, 110109 frames, score 1, max score 9
# Completed 176 games, 440 rewards, 110290 frames, score 0, max score 9
# Completed 177 games, 441 rewards, 110498 frames, score 0, max score 9
# Completed 178 games, 443 rewards, 110961 frames, score 1, max score 9
# Completed 179 games, 446 rewards, 111462 frames, score 2, max score 9
# Completed 180 games, 448 rewards, 111996 frames, score 1, max score 9
# Completed 181 games, 451 rewards, 112630 frames, score 2, max score 9
# Completed 182 games, 457 rewards, 113548 frames, score 5, max score 9
# Completed 183 games, 459 rewards, 114008 frames, score 1, max score 9
# Completed 184 games, 461 rewards, 114349 frames, score 1, max score 9
# Completed 185 games, 463 rewards, 114786 frames, score 1, max score 9
# Completed 186 games, 465 rewards, 115191 frames, score 1, max score 9
# Completed 187 games, 467 rewards, 115688 frames, score 1, max score 9
# Completed 188 games, 469 rewards, 116200 frames, score 1, max score 9
# Completed 189 games, 470 rewards, 116454 frames, score 0, max score 9
# Completed 190 games, 473 rewards, 117065 frames, score 2, max score 9
# Completed 191 games, 475 rewards, 117599 frames, score 1, max score 9
# Completed 192 games, 476 rewards, 117853 frames, score 0, max score 9
# Completed 193 games, 480 rewards, 118803 frames, score 3, max score 9
# Completed 194 games, 482 rewards, 119155 frames, score 1, max score 9
# Completed 195 games, 485 rewards, 120000 frames, score 2, max score 9
# Completed 196 games, 486 rewards, 120181 frames, score 0, max score 9
# Completed 197 games, 487 rewards, 120435 frames, score 0, max score 9
# Completed 198 games, 488 rewards, 120689 frames, score 0, max score 9
# Completed 199 games, 490 rewards, 121054 frames, score 1, max score 9
# Completed 200 games, 492 rewards, 121486 frames, score 1, max score 9
# Completed 201 games, 494 rewards, 122220 frames, score 1, max score 9
# Completed 202 games, 496 rewards, 122672 frames, score 1, max score 9
# Completed 203 games, 498 rewards, 123109 frames, score 1, max score 9
# Completed 204 games, 501 rewards, 123828 frames, score 2, max score 9
# Completed 205 games, 503 rewards, 124460 frames, score 1, max score 9
# Completed 206 games, 506 rewards, 124976 frames, score 2, max score 9
# Completed 207 games, 507 rewards, 125157 frames, score 0, max score 9
# Completed 208 games, 510 rewards, 125709 frames, score 2, max score 9
# Completed 209 games, 511 rewards, 125963 frames, score 0, max score 9
# Completed 210 games, 512 rewards, 126171 frames, score 0, max score 9
# Completed 211 games, 514 rewards, 126722 frames, score 1, max score 9
# Completed 212 games, 515 rewards, 126903 frames, score 0, max score 9
# Completed 213 games, 516 rewards, 127111 frames, score 0, max score 9
# Completed 214 games, 520 rewards, 127838 frames, score 3, max score 9
# Completed 215 games, 523 rewards, 128368 frames, score 2, max score 9
# Completed 216 games, 526 rewards, 129697 frames, score 2, max score 9
# Completed 217 games, 528 rewards, 130231 frames, score 1, max score 9
# Completed 218 games, 529 rewards, 130439 frames, score 0, max score 9
# Completed 219 games, 530 rewards, 130647 frames, score 0, max score 9
# Completed 220 games, 531 rewards, 130901 frames, score 0, max score 9
# Completed 221 games, 533 rewards, 131820 frames, score 1, max score 9
# Completed 222 games, 537 rewards, 132524 frames, score 3, max score 9
# Completed 223 games, 538 rewards, 132778 frames, score 0, max score 9
# Completed 224 games, 541 rewards, 133464 frames, score 2, max score 9
# Completed 225 games, 543 rewards, 134066 frames, score 1, max score 9
# Completed 226 games, 544 rewards, 134274 frames, score 0, max score 9
# Completed 227 games, 546 rewards, 134680 frames, score 1, max score 9
# Completed 228 games, 557 rewards, 137142 frames, score 10, max score 10
# Completed 229 games, 558 rewards, 137350 frames, score 0, max score 10
# Completed 230 games, 562 rewards, 138120 frames, score 3, max score 10
# Completed 231 games, 564 rewards, 138632 frames, score 1, max score 10
# Completed 232 games, 568 rewards, 139456 frames, score 3, max score 10
# Completed 233 games, 570 rewards, 139862 frames, score 1, max score 10
# Completed 234 games, 572 rewards, 140335 frames, score 1, max score 10
# Completed 235 games, 573 rewards, 140516 frames, score 0, max score 10
# Completed 236 games, 576 rewards, 141216 frames, score 2, max score 10
# Completed 237 games, 578 rewards, 141728 frames, score 1, max score 10
# Completed 238 games, 579 rewards, 141936 frames, score 0, max score 10
# Completed 239 games, 583 rewards, 142680 frames, score 3, max score 10
# Completed 240 games, 584 rewards, 142888 frames, score 0, max score 10
# Completed 241 games, 589 rewards, 143839 frames, score 4, max score 10
# Completed 242 games, 592 rewards, 144707 frames, score 2, max score 10
# Completed 243 games, 593 rewards, 144888 frames, score 0, max score 10
# Completed 244 games, 595 rewards, 145367 frames, score 1, max score 10
# Completed 245 games, 597 rewards, 145901 frames, score 1, max score 10
# Completed 246 games, 600 rewards, 147548 frames, score 2, max score 10
# Completed 247 games, 603 rewards, 148054 frames, score 2, max score 10
# Completed 248 games, 606 rewards, 149011 frames, score 2, max score 10
# Completed 249 games, 609 rewards, 149822 frames, score 2, max score 10
# Completed 250 games, 611 rewards, 150484 frames, score 1, max score 10
# Completed 251 games, 613 rewards, 150996 frames, score 1, max score 10
# Completed 252 games, 616 rewards, 151495 frames, score 2, max score 10
# Completed 253 games, 617 rewards, 151703 frames, score 0, max score 10
# Completed 254 games, 619 rewards, 152070 frames, score 1, max score 10
# Completed 255 games, 622 rewards, 152576 frames, score 2, max score 10
# Completed 256 games, 624 rewards, 153039 frames, score 1, max score 10
# Completed 257 games, 625 rewards, 153220 frames, score 0, max score 10
# Completed 258 games, 629 rewards, 154435 frames, score 3, max score 10
# Completed 259 games, 632 rewards, 155184 frames, score 2, max score 10
# Completed 260 games, 636 rewards, 156304 frames, score 3, max score 10
# Completed 261 games, 640 rewards, 157137 frames, score 3, max score 10
# Completed 262 games, 641 rewards, 157391 frames, score 0, max score 10
# Completed 263 games, 644 rewards, 158254 frames, score 2, max score 10
# Completed 264 games, 645 rewards, 158462 frames, score 0, max score 10
# Completed 265 games, 646 rewards, 158716 frames, score 0, max score 10
# Completed 266 games, 647 rewards, 158897 frames, score 0, max score 10
# Completed 267 games, 652 rewards, 160351 frames, score 4, max score 10
# Completed 268 games, 658 rewards, 161860 frames, score 5, max score 10
# Completed 269 games, 659 rewards, 162041 frames, score 0, max score 10
# Completed 270 games, 662 rewards, 162654 frames, score 2, max score 10
# Completed 271 games, 663 rewards, 162862 frames, score 0, max score 10
# Completed 272 games, 665 rewards, 163322 frames, score 1, max score 10
# Completed 273 games, 669 rewards, 164021 frames, score 3, max score 10
# Completed 274 games, 671 rewards, 164509 frames, score 1, max score 10
# Completed 275 games, 675 rewards, 165563 frames, score 3, max score 10
# Completed 276 games, 680 rewards, 166491 frames, score 4, max score 10
# Completed 277 games, 684 rewards, 167342 frames, score 3, max score 10
# Completed 278 games, 691 rewards, 169647 frames, score 6, max score 10
# Completed 279 games, 692 rewards, 169855 frames, score 0, max score 10
# Completed 280 games, 696 rewards, 170673 frames, score 3, max score 10
# Completed 281 games, 699 rewards, 171384 frames, score 2, max score 10
# Completed 282 games, 701 rewards, 171767 frames, score 1, max score 10
# Completed 283 games, 705 rewards, 172468 frames, score 3, max score 10
# Completed 284 games, 706 rewards, 172649 frames, score 0, max score 10
# Completed 285 games, 707 rewards, 172903 frames, score 0, max score 10
# Completed 286 games, 710 rewards, 173660 frames, score 2, max score 10
# Completed 287 games, 711 rewards, 173868 frames, score 0, max score 10
# Completed 288 games, 713 rewards, 174266 frames, score 1, max score 10
# Completed 289 games, 715 rewards, 174729 frames, score 1, max score 10
# Completed 290 games, 720 rewards, 176360 frames, score 4, max score 10
# Completed 291 games, 725 rewards, 177295 frames, score 4, max score 10
# Completed 292 games, 730 rewards, 178161 frames, score 4, max score 10
# Completed 293 games, 733 rewards, 178724 frames, score 2, max score 10
# Completed 294 games, 735 rewards, 179107 frames, score 1, max score 10
# Completed 295 games, 737 rewards, 179544 frames, score 1, max score 10
# Completed 296 games, 742 rewards, 180915 frames, score 4, max score 10
# Completed 297 games, 744 rewards, 181415 frames, score 1, max score 10
# Completed 298 games, 750 rewards, 183226 frames, score 5, max score 10
# Completed 299 games, 754 rewards, 183900 frames, score 3, max score 10
# Completed 300 games, 755 rewards, 184154 frames, score 0, max score 10
# Completed 301 games, 758 rewards, 185078 frames, score 2, max score 10
# Completed 302 games, 759 rewards, 185259 frames, score 0, max score 10
# Completed 303 games, 762 rewards, 186082 frames, score 2, max score 10
# Completed 304 games, 763 rewards, 186290 frames, score 0, max score 10
# Completed 305 games, 765 rewards, 186706 frames, score 1, max score 10
# Completed 306 games, 768 rewards, 187243 frames, score 2, max score 10
# Completed 307 games, 771 rewards, 188046 frames, score 2, max score 10
# Completed 308 games, 778 rewards, 189115 frames, score 6, max score 10
# Completed 309 games, 780 rewards, 189717 frames, score 1, max score 10
# Completed 310 games, 781 rewards, 189898 frames, score 0, max score 10
# Completed 311 games, 785 rewards, 190516 frames, score 3, max score 10
# Completed 312 games, 787 rewards, 190953 frames, score 1, max score 10
# Completed 313 games, 790 rewards, 191643 frames, score 2, max score 10
# Completed 314 games, 791 rewards, 191824 frames, score 0, max score 10
# Completed 315 games, 793 rewards, 192486 frames, score 1, max score 10
# Completed 316 games, 794 rewards, 192667 frames, score 0, max score 10
# Completed 317 games, 796 rewards, 193054 frames, score 1, max score 10
# Completed 318 games, 804 rewards, 194926 frames, score 7, max score 10
# Completed 319 games, 805 rewards, 195180 frames, score 0, max score 10
# Completed 320 games, 808 rewards, 195862 frames, score 2, max score 10
# Completed 321 games, 809 rewards, 196043 frames, score 0, max score 10
# Completed 322 games, 811 rewards, 196540 frames, score 1, max score 10
# Completed 323 games, 815 rewards, 197713 frames, score 3, max score 10
# Completed 324 games, 817 rewards, 198632 frames, score 1, max score 10
# Completed 325 games, 818 rewards, 198886 frames, score 0, max score 10
# Completed 326 games, 824 rewards, 199845 frames, score 5, max score 10
# Completed 327 games, 825 rewards, 200099 frames, score 0, max score 10
# Completed 328 games, 826 rewards, 200280 frames, score 0, max score 10
# Completed 329 games, 829 rewards, 201006 frames, score 2, max score 10
# Completed 330 games, 830 rewards, 201187 frames, score 0, max score 10
# Completed 331 games, 831 rewards, 201395 frames, score 0, max score 10
# Completed 332 games, 835 rewards, 202049 frames, score 3, max score 10
# Completed 333 games, 836 rewards, 202257 frames, score 0, max score 10
# Completed 334 games, 837 rewards, 202438 frames, score 0, max score 10
# Completed 335 games, 844 rewards, 204720 frames, score 6, max score 10
# Completed 336 games, 847 rewards, 206176 frames, score 2, max score 10
# Completed 337 games, 849 rewards, 206590 frames, score 1, max score 10
# Completed 338 games, 851 rewards, 207053 frames, score 1, max score 10
# Completed 339 games, 852 rewards, 207234 frames, score 0, max score 10
# Completed 340 games, 855 rewards, 208011 frames, score 2, max score 10
# Completed 341 games, 861 rewards, 209712 frames, score 5, max score 10
# Completed 342 games, 866 rewards, 210824 frames, score 4, max score 10
# Completed 343 games, 871 rewards, 211984 frames, score 4, max score 10
# Completed 344 games, 872 rewards, 212238 frames, score 0, max score 10
# Completed 345 games, 873 rewards, 212446 frames, score 0, max score 10
# Completed 346 games, 876 rewards, 214470 frames, score 2, max score 10
# Completed 347 games, 878 rewards, 214967 frames, score 1, max score 10
# Completed 348 games, 879 rewards, 215175 frames, score 0, max score 10
# Completed 349 games, 880 rewards, 215356 frames, score 0, max score 10
# Completed 350 games, 883 rewards, 216204 frames, score 2, max score 10
# Completed 351 games, 885 rewards, 216602 frames, score 1, max score 10
# Completed 352 games, 888 rewards, 218626 frames, score 2, max score 10
# Completed 353 games, 890 rewards, 219177 frames, score 1, max score 10
# Completed 354 games, 892 rewards, 219631 frames, score 1, max score 10
# Completed 355 games, 893 rewards, 219812 frames, score 0, max score 10
# Completed 356 games, 894 rewards, 219993 frames, score 0, max score 10
# Completed 357 games, 902 rewards, 221587 frames, score 7, max score 10
# Completed 358 games, 905 rewards, 222387 frames, score 2, max score 10
# Completed 359 games, 906 rewards, 222568 frames, score 0, max score 10
# Completed 360 games, 909 rewards, 223354 frames, score 2, max score 10
# Completed 361 games, 911 rewards, 223866 frames, score 1, max score 10
# Completed 362 games, 913 rewards, 224417 frames, score 1, max score 10
# Completed 363 games, 914 rewards, 224671 frames, score 0, max score 10
# Completed 364 games, 915 rewards, 224925 frames, score 0, max score 10
# Completed 365 games, 916 rewards, 225106 frames, score 0, max score 10
# Completed 366 games, 918 rewards, 225447 frames, score 1, max score 10
# Completed 367 games, 921 rewards, 226035 frames, score 2, max score 10
# Completed 368 games, 925 rewards, 226845 frames, score 3, max score 10
# Completed 369 games, 926 rewards, 227026 frames, score 0, max score 10
# Completed 370 games, 929 rewards, 227605 frames, score 2, max score 10
# Completed 371 games, 934 rewards, 228433 frames, score 4, max score 10
# Completed 372 games, 937 rewards, 229136 frames, score 2, max score 10
# Completed 373 games, 942 rewards, 231166 frames, score 4, max score 10
# Completed 374 games, 946 rewards, 232093 frames, score 3, max score 10
# Completed 375 games, 947 rewards, 232301 frames, score 0, max score 10
# Completed 376 games, 951 rewards, 233133 frames, score 3, max score 10
# Completed 377 games, 952 rewards, 233341 frames, score 0, max score 10
# Completed 378 games, 956 rewards, 235148 frames, score 3, max score 10
# Completed 379 games, 957 rewards, 235356 frames, score 0, max score 10
# Completed 380 games, 958 rewards, 235610 frames, score 0, max score 10
# Completed 381 games, 959 rewards, 235818 frames, score 0, max score 10
# Completed 382 games, 960 rewards, 236072 frames, score 0, max score 10
# Completed 383 games, 961 rewards, 236253 frames, score 0, max score 10
# Completed 384 games, 962 rewards, 236434 frames, score 0, max score 10
# Completed 385 games, 963 rewards, 236642 frames, score 0, max score 10
# Completed 386 games, 964 rewards, 236850 frames, score 0, max score 10
# Completed 387 games, 968 rewards, 237607 frames, score 3, max score 10
# Completed 388 games, 970 rewards, 237975 frames, score 1, max score 10
# Completed 389 games, 971 rewards, 238156 frames, score 0, max score 10
# Completed 390 games, 972 rewards, 238337 frames, score 0, max score 10
# Completed 391 games, 975 rewards, 239153 frames, score 2, max score 10
# Completed 392 games, 982 rewards, 240535 frames, score 6, max score 10
# Completed 393 games, 987 rewards, 241949 frames, score 4, max score 10
# Completed 394 games, 988 rewards, 242203 frames, score 0, max score 10
# Completed 395 games, 989 rewards, 242411 frames, score 0, max score 10
# Completed 396 games, 990 rewards, 242592 frames, score 0, max score 10
# Completed 397 games, 991 rewards, 242773 frames, score 0, max score 10
# Completed 398 games, 995 rewards, 244226 frames, score 3, max score 10
# Completed 399 games, 996 rewards, 244407 frames, score 0, max score 10
# Completed 400 games, 1000 rewards, 245247 frames, score 3, max score 10
# Completed 401 games, 1001 rewards, 245455 frames, score 0, max score 10
# Completed 402 games, 1005 rewards, 246175 frames, score 3, max score 10
# Completed 403 games, 1006 rewards, 246356 frames, score 0, max score 10
# Completed 404 games, 1009 rewards, 246997 frames, score 2, max score 10
# Completed 405 games, 1012 rewards, 247849 frames, score 2, max score 10
# Completed 406 games, 1013 rewards, 248057 frames, score 0, max score 10
# Completed 407 games, 1015 rewards, 248409 frames, score 1, max score 10
# Completed 408 games, 1017 rewards, 249282 frames, score 1, max score 10
# Completed 409 games, 1023 rewards, 252069 frames, score 5, max score 10
# Completed 410 games, 1024 rewards, 252277 frames, score 0, max score 10
# Completed 411 games, 1026 rewards, 252774 frames, score 1, max score 10
# Completed 412 games, 1029 rewards, 253874 frames, score 2, max score 10
# Completed 413 games, 1030 rewards, 254128 frames, score 0, max score 10
# Completed 414 games, 1033 rewards, 254741 frames, score 2, max score 10
# Completed 415 games, 1035 rewards, 255109 frames, score 1, max score 10
# Completed 416 games, 1036 rewards, 255317 frames, score 0, max score 10
# Completed 417 games, 1037 rewards, 255571 frames, score 0, max score 10
# Completed 418 games, 1038 rewards, 255779 frames, score 0, max score 10
# Completed 419 games, 1043 rewards, 256679 frames, score 4, max score 10
# Completed 420 games, 1050 rewards, 257849 frames, score 6, max score 10
# Completed 421 games, 1051 rewards, 258030 frames, score 0, max score 10
# Completed 422 games, 1053 rewards, 258382 frames, score 1, max score 10
# Completed 423 games, 1054 rewards, 258636 frames, score 0, max score 10
# Completed 424 games, 1056 rewards, 259298 frames, score 1, max score 10
# Completed 425 games, 1058 rewards, 259639 frames, score 1, max score 10
# Completed 426 games, 1059 rewards, 259820 frames, score 0, max score 10
# Completed 427 games, 1061 rewards, 260226 frames, score 1, max score 10
# Completed 428 games, 1062 rewards, 260407 frames, score 0, max score 10
# Completed 429 games, 1069 rewards, 264105 frames, score 6, max score 10
# Completed 430 games, 1073 rewards, 264994 frames, score 3, max score 10
# Completed 431 games, 1074 rewards, 265202 frames, score 0, max score 10
# Completed 432 games, 1076 rewards, 265864 frames, score 1, max score 10
# Completed 433 games, 1079 rewards, 266431 frames, score 2, max score 10
# Completed 434 games, 1080 rewards, 266639 frames, score 0, max score 10
# Completed 435 games, 1082 rewards, 267229 frames, score 1, max score 10
# Completed 436 games, 1088 rewards, 268248 frames, score 5, max score 10
# Completed 437 games, 1090 rewards, 268736 frames, score 1, max score 10
# Completed 438 games, 1093 rewards, 269545 frames, score 2, max score 10
# Completed 439 games, 1094 rewards, 269753 frames, score 0, max score 10
# Completed 440 games, 1095 rewards, 270007 frames, score 0, max score 10
# Completed 441 games, 1096 rewards, 270188 frames, score 0, max score 10
# Completed 442 games, 1097 rewards, 270369 frames, score 0, max score 10
# Completed 443 games, 1099 rewards, 270756 frames, score 1, max score 10
# Completed 444 games, 1101 rewards, 271123 frames, score 1, max score 10
# Completed 445 games, 1102 rewards, 271304 frames, score 0, max score 10
# Completed 446 games, 1104 rewards, 271672 frames, score 1, max score 10
# Completed 447 games, 1106 rewards, 272169 frames, score 1, max score 10
# Completed 448 games, 1107 rewards, 272423 frames, score 0, max score 10
# Completed 449 games, 1110 rewards, 273108 frames, score 2, max score 10
# Completed 450 games, 1115 rewards, 274118 frames, score 4, max score 10
# Completed 451 games, 1117 rewards, 274512 frames, score 1, max score 10
# Completed 452 games, 1119 rewards, 274918 frames, score 1, max score 10
# Completed 453 games, 1122 rewards, 275557 frames, score 2, max score 10
# Completed 454 games, 1126 rewards, 277471 frames, score 3, max score 10
# Completed 455 games, 1128 rewards, 277931 frames, score 1, max score 10
# Completed 456 games, 1132 rewards, 278755 frames, score 3, max score 10
# Completed 457 games, 1135 rewards, 279344 frames, score 2, max score 10
# Completed 458 games, 1137 rewards, 279841 frames, score 1, max score 10
# Completed 459 games, 1141 rewards, 280818 frames, score 3, max score 10
# Completed 460 games, 1142 rewards, 280999 frames, score 0, max score 10
# Completed 461 games, 1143 rewards, 281180 frames, score 0, max score 10
# Completed 462 games, 1144 rewards, 281388 frames, score 0, max score 10
# Completed 463 games, 1145 rewards, 281596 frames, score 0, max score 10
# Completed 464 games, 1148 rewards, 282553 frames, score 2, max score 10
# Completed 465 games, 1151 rewards, 283244 frames, score 2, max score 10
# Completed 466 games, 1155 rewards, 285923 frames, score 3, max score 10
# Completed 467 games, 1158 rewards, 286557 frames, score 2, max score 10
# Completed 468 games, 1161 rewards, 287262 frames, score 2, max score 10
# Completed 469 games, 1168 rewards, 289087 frames, score 6, max score 10
# Completed 470 games, 1170 rewards, 289509 frames, score 1, max score 10
# Completed 471 games, 1171 rewards, 289690 frames, score 0, max score 10
# Completed 472 games, 1172 rewards, 289944 frames, score 0, max score 10
# Completed 473 games, 1177 rewards, 294176 frames, score 4, max score 10
# Completed 474 games, 1182 rewards, 295059 frames, score 4, max score 10
# Completed 475 games, 1188 rewards, 296357 frames, score 5, max score 10
# Completed 476 games, 1189 rewards, 296611 frames, score 0, max score 10
# Completed 477 games, 1191 rewards, 297162 frames, score 1, max score 10
# Completed 478 games, 1193 rewards, 297599 frames, score 1, max score 10
# Completed 479 games, 1195 rewards, 297997 frames, score 1, max score 10
# Completed 480 games, 1196 rewards, 298205 frames, score 0, max score 10
# Completed 481 games, 1197 rewards, 298459 frames, score 0, max score 10
# Completed 482 games, 1199 rewards, 298850 frames, score 1, max score 10
# Completed 483 games, 1200 rewards, 299058 frames, score 0, max score 10
# Completed 484 games, 1203 rewards, 299553 frames, score 2, max score 10
# Completed 485 games, 1204 rewards, 299807 frames, score 0, max score 10
# Completed 486 games, 1207 rewards, 300344 frames, score 2, max score 10
# Completed 487 games, 1209 rewards, 300895 frames, score 1, max score 10
# Completed 488 games, 1210 rewards, 301103 frames, score 0, max score 10
# Completed 489 games, 1215 rewards, 302486 frames, score 4, max score 10
# Completed 490 games, 1221 rewards, 304056 frames, score 5, max score 10
# Completed 491 games, 1222 rewards, 304237 frames, score 0, max score 10
# Completed 492 games, 1223 rewards, 304491 frames, score 0, max score 10
# Completed 493 games, 1225 rewards, 305003 frames, score 1, max score 10
# Completed 494 games, 1230 rewards, 306518 frames, score 4, max score 10
# Completed 495 games, 1233 rewards, 307249 frames, score 2, max score 10
# Completed 496 games, 1235 rewards, 307911 frames, score 1, max score 10
# Completed 497 games, 1237 rewards, 308423 frames, score 1, max score 10
# Completed 498 games, 1238 rewards, 308631 frames, score 0, max score 10
# Completed 499 games, 1239 rewards, 308839 frames, score 0, max score 10
# Completed 500 games, 1242 rewards, 309639 frames, score 2, max score 10
# Completed 501 games, 1245 rewards, 310947 frames, score 2, max score 10
# Completed 502 games, 1247 rewards, 311375 frames, score 1, max score 10
# Completed 503 games, 1249 rewards, 311887 frames, score 1, max score 10
# Completed 504 games, 1253 rewards, 312662 frames, score 3, max score 10
# Completed 505 games, 1255 rewards, 313324 frames, score 1, max score 10
# Completed 506 games, 1256 rewards, 313505 frames, score 0, max score 10
# Completed 507 games, 1258 rewards, 313873 frames, score 1, max score 10
# Completed 508 games, 1260 rewards, 314463 frames, score 1, max score 10
# Completed 509 games, 1264 rewards, 315663 frames, score 3, max score 10
# Completed 510 games, 1266 rewards, 316031 frames, score 1, max score 10
# Completed 511 games, 1269 rewards, 316559 frames, score 2, max score 10
# Completed 512 games, 1276 rewards, 317766 frames, score 6, max score 10
# Completed 513 games, 1278 rewards, 318107 frames, score 1, max score 10
# Completed 514 games, 1281 rewards, 319009 frames, score 2, max score 10
# Completed 515 games, 1282 rewards, 319190 frames, score 0, max score 10
# Completed 516 games, 1284 rewards, 319650 frames, score 1, max score 10
# Completed 517 games, 1286 rewards, 320312 frames, score 1, max score 10
# Completed 518 games, 1289 rewards, 320887 frames, score 2, max score 10
# Completed 519 games, 1290 rewards, 321095 frames, score 0, max score 10
# Completed 520 games, 1292 rewards, 321583 frames, score 1, max score 10
# Completed 521 games, 1296 rewards, 323029 frames, score 3, max score 10
# Completed 522 games, 1298 rewards, 323526 frames, score 1, max score 10
# Completed 523 games, 1302 rewards, 324369 frames, score 3, max score 10
# Completed 524 games, 1303 rewards, 324550 frames, score 0, max score 10
# Completed 525 games, 1305 rewards, 325010 frames, score 1, max score 10
# Completed 526 games, 1306 rewards, 325264 frames, score 0, max score 10
# Completed 527 games, 1310 rewards, 326165 frames, score 3, max score 10
# Completed 528 games, 1311 rewards, 326419 frames, score 0, max score 10
# Completed 529 games, 1317 rewards, 328176 frames, score 5, max score 10
# Completed 530 games, 1323 rewards, 329176 frames, score 5, max score 10
# Completed 531 games, 1326 rewards, 329704 frames, score 2, max score 10
# Completed 532 games, 1328 rewards, 330102 frames, score 1, max score 10
# Completed 533 games, 1331 rewards, 330857 frames, score 2, max score 10
# Completed 534 games, 1342 rewards, 334577 frames, score 10, max score 10
# Completed 535 games, 1343 rewards, 334785 frames, score 0, max score 10
# Completed 536 games, 1344 rewards, 334966 frames, score 0, max score 10
# Completed 537 games, 1350 rewards, 335986 frames, score 5, max score 10
# Completed 538 games, 1351 rewards, 336240 frames, score 0, max score 10
# Completed 539 games, 1353 rewards, 336592 frames, score 1, max score 10
# Completed 540 games, 1358 rewards, 337757 frames, score 4, max score 10
# Completed 541 games, 1360 rewards, 338149 frames, score 1, max score 10
# Completed 542 games, 1364 rewards, 339304 frames, score 3, max score 10
# Completed 543 games, 1366 rewards, 339709 frames, score 1, max score 10
# Completed 544 games, 1368 rewards, 340107 frames, score 1, max score 10
# Completed 545 games, 1371 rewards, 341162 frames, score 2, max score 10
# Completed 546 games, 1372 rewards, 341370 frames, score 0, max score 10
# Completed 547 games, 1375 rewards, 341917 frames, score 2, max score 10
# Completed 548 games, 1376 rewards, 342171 frames, score 0, max score 10
# Completed 549 games, 1378 rewards, 342577 frames, score 1, max score 10
# Completed 550 games, 1382 rewards, 343279 frames, score 3, max score 10
# Completed 551 games, 1385 rewards, 343894 frames, score 2, max score 10
# Completed 552 games, 1388 rewards, 345428 frames, score 2, max score 10
# Completed 553 games, 1389 rewards, 345636 frames, score 0, max score 10
# Completed 554 games, 1391 rewards, 346148 frames, score 1, max score 10
# Completed 555 games, 1394 rewards, 346807 frames, score 2, max score 10
# Completed 556 games, 1405 rewards, 349265 frames, score 10, max score 10
# Completed 557 games, 1406 rewards, 349519 frames, score 0, max score 10
# Completed 558 games, 1412 rewards, 350558 frames, score 5, max score 10
# Completed 559 games, 1413 rewards, 350739 frames, score 0, max score 10
# Completed 560 games, 1417 rewards, 351588 frames, score 3, max score 10
# Completed 561 games, 1418 rewards, 351796 frames, score 0, max score 10
# Completed 562 games, 1423 rewards, 353765 frames, score 4, max score 10
# Completed 563 games, 1424 rewards, 353946 frames, score 0, max score 10
# Completed 564 games, 1429 rewards, 356708 frames, score 4, max score 10
# Completed 565 games, 1430 rewards, 356889 frames, score 0, max score 10
# Completed 566 games, 1431 rewards, 357143 frames, score 0, max score 10
# Completed 567 games, 1433 rewards, 357511 frames, score 1, max score 10
# Completed 568 games, 1434 rewards, 357692 frames, score 0, max score 10
# Completed 569 games, 1439 rewards, 358448 frames, score 4, max score 10
# Completed 570 games, 1440 rewards, 358656 frames, score 0, max score 10
# Completed 571 games, 1443 rewards, 359375 frames, score 2, max score 10
# Completed 572 games, 1445 rewards, 359863 frames, score 1, max score 10
# Completed 573 games, 1448 rewards, 360464 frames, score 2, max score 10
# Completed 574 games, 1450 rewards, 361126 frames, score 1, max score 10
# Completed 575 games, 1453 rewards, 361741 frames, score 2, max score 10
# Completed 576 games, 1458 rewards, 363169 frames, score 4, max score 10
# Completed 577 games, 1461 rewards, 363757 frames, score 2, max score 10
# Completed 578 games, 1463 rewards, 364491 frames, score 1, max score 10
# Completed 579 games, 1466 rewards, 365287 frames, score 2, max score 10
# Completed 580 games, 1468 rewards, 365724 frames, score 1, max score 10
# Completed 581 games, 1470 rewards, 366184 frames, score 1, max score 10
# Completed 582 games, 1472 rewards, 366612 frames, score 1, max score 10
# Completed 583 games, 1473 rewards, 366866 frames, score 0, max score 10
# Completed 584 games, 1474 rewards, 367120 frames, score 0, max score 10
# Completed 585 games, 1478 rewards, 367910 frames, score 3, max score 10
# Completed 586 games, 1486 rewards, 369503 frames, score 7, max score 10
# Completed 587 games, 1494 rewards, 370965 frames, score 7, max score 10
# Completed 588 games, 1500 rewards, 371917 frames, score 5, max score 10
# Completed 589 games, 1504 rewards, 372588 frames, score 3, max score 10
# Completed 590 games, 1508 rewards, 373624 frames, score 3, max score 10
# Completed 591 games, 1512 rewards, 374610 frames, score 3, max score 10
# Completed 592 games, 1514 rewards, 375200 frames, score 1, max score 10
# Completed 593 games, 1515 rewards, 375408 frames, score 0, max score 10
# Completed 594 games, 1517 rewards, 375836 frames, score 1, max score 10
# Completed 595 games, 1519 rewards, 376234 frames, score 1, max score 10
# Completed 596 games, 1521 rewards, 376746 frames, score 1, max score 10
# Completed 597 games, 1524 rewards, 377703 frames, score 2, max score 10
# Completed 598 games, 1529 rewards, 378615 frames, score 4, max score 10
# Completed 599 games, 1532 rewards, 379929 frames, score 2, max score 10
# Completed 600 games, 1540 rewards, 381255 frames, score 7, max score 10
# Completed 601 games, 1544 rewards, 382622 frames, score 3, max score 10
# Completed 602 games, 1548 rewards, 383353 frames, score 3, max score 10
# Completed 603 games, 1550 rewards, 383694 frames, score 1, max score 10
# Completed 604 games, 1552 rewards, 384061 frames, score 1, max score 10
# Completed 605 games, 1557 rewards, 385374 frames, score 4, max score 10
# Completed 606 games, 1562 rewards, 386223 frames, score 4, max score 10
# Completed 607 games, 1564 rewards, 386774 frames, score 1, max score 10
# Completed 608 games, 1567 rewards, 387521 frames, score 2, max score 10
# Completed 609 games, 1576 rewards, 389765 frames, score 8, max score 10
# Completed 610 games, 1577 rewards, 389946 frames, score 0, max score 10
# Completed 611 games, 1578 rewards, 390200 frames, score 0, max score 10
# Completed 612 games, 1582 rewards, 392961 frames, score 3, max score 10
# Completed 613 games, 1586 rewards, 393793 frames, score 3, max score 10
# Completed 614 games, 1597 rewards, 396085 frames, score 10, max score 10
# Completed 615 games, 1598 rewards, 396266 frames, score 0, max score 10
# Completed 616 games, 1602 rewards, 396997 frames, score 3, max score 10
# Completed 617 games, 1604 rewards, 397365 frames, score 1, max score 10
# Completed 618 games, 1605 rewards, 397619 frames, score 0, max score 10
# Completed 619 games, 1606 rewards, 397827 frames, score 0, max score 10
# Completed 620 games, 1612 rewards, 399951 frames, score 5, max score 10
# Completed 621 games, 1613 rewards, 400132 frames, score 0, max score 10
# Completed 622 games, 1626 rewards, 402382 frames, score 12, max score 12
# Completed 623 games, 1627 rewards, 402563 frames, score 0, max score 12
# Completed 624 games, 1641 rewards, 408146 frames, score 13, max score 13
# Completed 625 games, 1650 rewards, 410154 frames, score 8, max score 13
# Completed 626 games, 1651 rewards, 410362 frames, score 0, max score 13
# Completed 627 games, 1652 rewards, 410616 frames, score 0, max score 13
# Completed 628 games, 1654 rewards, 410983 frames, score 1, max score 13
# Completed 629 games, 1656 rewards, 411534 frames, score 1, max score 13
# Completed 630 games, 1659 rewards, 412430 frames, score 2, max score 13
# Completed 631 games, 1666 rewards, 415331 frames, score 6, max score 13
# Completed 632 games, 1669 rewards, 415946 frames, score 2, max score 13
# Completed 633 games, 1671 rewards, 416443 frames, score 1, max score 13
# Completed 634 games, 1675 rewards, 417118 frames, score 3, max score 13
# Completed 635 games, 1687 rewards, 418962 frames, score 11, max score 13
# Completed 636 games, 1692 rewards, 419976 frames, score 4, max score 13
# Completed 637 games, 1694 rewards, 420374 frames, score 1, max score 13
# Completed 638 games, 1695 rewards, 420582 frames, score 0, max score 13
# Completed 639 games, 1696 rewards, 420763 frames, score 0, max score 13
# Completed 640 games, 1708 rewards, 423112 frames, score 11, max score 13
# Completed 641 games, 1711 rewards, 423993 frames, score 2, max score 13
# Completed 642 games, 1716 rewards, 425890 frames, score 4, max score 13
# Completed 643 games, 1718 rewards, 426552 frames, score 1, max score 13
# Completed 644 games, 1719 rewards, 426760 frames, score 0, max score 13
# Completed 645 games, 1724 rewards, 427842 frames, score 4, max score 13
# Completed 646 games, 1727 rewards, 428322 frames, score 2, max score 13
# Completed 647 games, 1731 rewards, 429627 frames, score 3, max score 13
# Completed 648 games, 1733 rewards, 429995 frames, score 1, max score 13
# Completed 649 games, 1734 rewards, 430249 frames, score 0, max score 13
# Completed 650 games, 1735 rewards, 430457 frames, score 0, max score 13
# Completed 651 games, 1738 rewards, 431012 frames, score 2, max score 13
# Completed 652 games, 1739 rewards, 431220 frames, score 0, max score 13
# Completed 653 games, 1741 rewards, 431683 frames, score 1, max score 13
# Completed 654 games, 1747 rewards, 432986 frames, score 5, max score 13
# Completed 655 games, 1750 rewards, 433643 frames, score 2, max score 13
# Completed 656 games, 1753 rewards, 434244 frames, score 2, max score 13
# Completed 657 games, 1755 rewards, 434631 frames, score 1, max score 13
# Completed 658 games, 1761 rewards, 436348 frames, score 5, max score 13
# Completed 659 games, 1765 rewards, 437311 frames, score 3, max score 13
# Completed 660 games, 1768 rewards, 437899 frames, score 2, max score 13
# Completed 661 games, 1769 rewards, 438080 frames, score 0, max score 13
# Completed 662 games, 1773 rewards, 439638 frames, score 3, max score 13
# Completed 663 games, 1775 rewards, 440101 frames, score 1, max score 13
# Completed 664 games, 1781 rewards, 441591 frames, score 5, max score 13
# Completed 665 games, 1782 rewards, 441772 frames, score 0, max score 13
# Completed 666 games, 1784 rewards, 442209 frames, score 1, max score 13
# Completed 667 games, 1788 rewards, 443632 frames, score 3, max score 13
# Completed 668 games, 1791 rewards, 444167 frames, score 2, max score 13
# Completed 669 games, 1793 rewards, 444581 frames, score 1, max score 13
# Completed 670 games, 1794 rewards, 444762 frames, score 0, max score 13
# Completed 671 games, 1798 rewards, 445641 frames, score 3, max score 13
# Completed 672 games, 1801 rewards, 446406 frames, score 2, max score 13
# Completed 673 games, 1803 rewards, 446918 frames, score 1, max score 13
# Completed 674 games, 1810 rewards, 448125 frames, score 6, max score 13
# Completed 675 games, 1817 rewards, 449971 frames, score 6, max score 13
# Completed 676 games, 1819 rewards, 450483 frames, score 1, max score 13
# Completed 677 games, 1823 rewards, 451272 frames, score 3, max score 13
# Completed 678 games, 1825 rewards, 451700 frames, score 1, max score 13
# Completed 679 games, 1829 rewards, 452712 frames, score 3, max score 13
# ...
# Completed 4797 games, 50672 rewards, 11642865 frames, score 64, max score 512
# Completed 4798 games, 50779 rewards, 11659424 frames, score 106, max score 512
# Completed 4799 games, 51129 rewards, 11726797 frames, score 349, max score 512
# Completed 4800 games, 51160 rewards, 11735558 frames, score 30, max score 512
# Completed 4801 games, 51254 rewards, 11753174 frames, score 93, max score 512
# Completed 4802 games, 51277 rewards, 11756919 frames, score 22, max score 512
# Completed 4803 games, 51367 rewards, 11772056 frames, score 89, max score 512
# Completed 4804 games, 51432 rewards, 11783534 frames, score 64, max score 512
# Completed 4805 games, 51832 rewards, 11865684 frames, score 399, max score 512
# Completed 4806 games, 51890 rewards, 11874922 frames, score 57, max score 512
# Completed 4807 games, 52339 rewards, 11946786 frames, score 448, max score 512
# Completed 4808 games, 52575 rewards, 11984732 frames, score 235, max score 512
# Completed 4809 games, 52729 rewards, 12010576 frames, score 153, max score 512
# Completed 4810 games, 52753 rewards, 12015536 frames, score 23, max score 512
# Completed 4811 games, 52773 rewards, 12019523 frames, score 19, max score 512
# Completed 4812 games, 52839 rewards, 12029521 frames, score 65, max score 512
# Completed 4813 games, 53022 rewards, 12068031 frames, score 182, max score 512
# Completed 4814 games, 53796 rewards, 12216140 frames, score 773, max score 773
# Completed 4815 games, 54188 rewards, 12277822 frames, score 391, max score 773
# Completed 4816 games, 54239 rewards, 12286399 frames, score 50, max score 773
# Completed 4817 games, 54334 rewards, 12308563 frames, score 94, max score 773
# Completed 4818 games, 54375 rewards, 12321460 frames, score 40, max score 773
# Completed 4819 games, 54417 rewards, 12327773 frames, score 41, max score 773
# Completed 4820 games, 54427 rewards, 12329309 frames, score 9, max score 773
# Completed 4821 games, 55025 rewards, 12420609 frames, score 597, max score 773
# Completed 4822 games, 55075 rewards, 12428457 frames, score 49, max score 773
# Completed 4823 games, 55190 rewards, 12445342 frames, score 114, max score 773
# Completed 4824 games, 55620 rewards, 12522497 frames, score 429, max score 773
# Completed 4825 games, 55940 rewards, 12585316 frames, score 319, max score 773
# Completed 4826 games, 56035 rewards, 12601220 frames, score 94, max score 773
# Completed 4827 games, 56225 rewards, 12630948 frames, score 189, max score 773
# Completed 4828 games, 56329 rewards, 12646914 frames, score 103, max score 773
# Completed 4829 games, 56512 rewards, 12674755 frames, score 182, max score 773
# Completed 4830 games, 56872 rewards, 12735072 frames, score 359, max score 773
# Completed 4831 games, 56972 rewards, 12750916 frames, score 99, max score 773
# Completed 4832 games, 57026 rewards, 12759062 frames, score 53, max score 773
# Completed 4833 games, 57489 rewards, 12833370 frames, score 462, max score 773
# Completed 4834 games, 57642 rewards, 12858785 frames, score 152, max score 773
# Completed 4835 games, 57770 rewards, 12879189 frames, score 127, max score 773
# Completed 4836 games, 57785 rewards, 12881777 frames, score 14, max score 773
# Completed 4837 games, 57797 rewards, 12884451 frames, score 11, max score 773
# Completed 4838 games, 57986 rewards, 12914198 frames, score 188, max score 773
# Completed 4839 games, 58357 rewards, 12991412 frames, score 370, max score 773
# Completed 4840 games, 58720 rewards, 13058387 frames, score 362, max score 773
# Completed 4841 games, 58757 rewards, 13064599 frames, score 36, max score 773
# Completed 4842 games, 58834 rewards, 13076184 frames, score 76, max score 773
# Completed 4843 games, 58899 rewards, 13087167 frames, score 64, max score 773
# Completed 4844 games, 59117 rewards, 13128175 frames, score 217, max score 773
# Completed 4845 games, 59282 rewards, 13156889 frames, score 164, max score 773
# Completed 4846 games, 59874 rewards, 13258097 frames, score 591, max score 773
# Completed 4847 games, 59939 rewards, 13268881 frames, score 64, max score 773
# Completed 4848 games, 59988 rewards, 13277449 frames, score 48, max score 773
# Completed 4849 games, 60047 rewards, 13289499 frames, score 58, max score 773
# Completed 4850 games, 60171 rewards, 13309307 frames, score 123, max score 773
# Completed 4851 games, 60325 rewards, 13336443 frames, score 153, max score 773
# Completed 4852 games, 60434 rewards, 13360730 frames, score 108, max score 773
# Completed 4853 games, 60635 rewards, 13399319 frames, score 200, max score 773
# Completed 4854 games, 60783 rewards, 13421583 frames, score 147, max score 773
# Completed 4855 games, 60820 rewards, 13429478 frames, score 36, max score 773
# Completed 4856 games, 60835 rewards, 13434275 frames, score 14, max score 773
# Completed 4857 games, 60900 rewards, 13446574 frames, score 64, max score 773
# Completed 4858 games, 60920 rewards, 13450328 frames, score 19, max score 773
# Completed 4859 games, 61029 rewards, 13466660 frames, score 108, max score 773
# Completed 4860 games, 61051 rewards, 13472572 frames, score 21, max score 773
# Completed 4861 games, 61072 rewards, 13478008 frames, score 20, max score 773
# Completed 4862 games, 61153 rewards, 13493281 frames, score 80, max score 773
# Completed 4863 games, 61200 rewards, 13501536 frames, score 46, max score 773
# Completed 4864 games, 61242 rewards, 13507775 frames, score 41, max score 773
# Completed 4865 games, 61435 rewards, 13540406 frames, score 192, max score 773
# Completed 4866 games, 61498 rewards, 13551670 frames, score 62, max score 773
# Completed 4867 games, 61514 rewards, 13554580 frames, score 15, max score 773
# Completed 4868 games, 61534 rewards, 13558790 frames, score 19, max score 773
# Completed 4869 games, 61540 rewards, 13560321 frames, score 5, max score 773
# Completed 4870 games, 61547 rewards, 13561588 frames, score 6, max score 773
# Completed 4871 games, 61571 rewards, 13565136 frames, score 23, max score 773
# Completed 4872 games, 61602 rewards, 13569847 frames, score 30, max score 773
# Completed 4873 games, 61626 rewards, 13574317 frames, score 23, max score 773
# Completed 4874 games, 61642 rewards, 13585592 frames, score 15, max score 773
# Completed 4875 games, 61749 rewards, 13608148 frames, score 106, max score 773
# Completed 4876 games, 61767 rewards, 13611010 frames, score 17, max score 773
# Completed 4877 games, 61772 rewards, 13611943 frames, score 4, max score 773
# Completed 4878 games, 61816 rewards, 13619127 frames, score 43, max score 773
# Completed 4879 games, 61924 rewards, 13641135 frames, score 107, max score 773
# Completed 4880 games, 62001 rewards, 13653526 frames, score 76, max score 773
# Completed 4881 games, 62003 rewards, 13654260 frames, score 1, max score 773
# Completed 4882 games, 62032 rewards, 13660171 frames, score 28, max score 773
# Completed 4883 games, 62057 rewards, 13664458 frames, score 24, max score 773
# Completed 4884 games, 62067 rewards, 13666481 frames, score 9, max score 773
# Completed 4885 games, 62152 rewards, 13680852 frames, score 84, max score 773
# Completed 4886 games, 62175 rewards, 13687148 frames, score 22, max score 773
# Completed 4887 games, 62198 rewards, 13690853 frames, score 22, max score 773
# Completed 4888 games, 62201 rewards, 13691806 frames, score 2, max score 773
# Completed 4889 games, 62262 rewards, 13706338 frames, score 60, max score 773
# Completed 4890 games, 62270 rewards, 13707759 frames, score 7, max score 773
# Completed 4891 games, 62275 rewards, 13708841 frames, score 4, max score 773
# Completed 4892 games, 62303 rewards, 13714734 frames, score 27, max score 773
# Completed 4893 games, 62316 rewards, 13716980 frames, score 12, max score 773
# Completed 4894 games, 62339 rewards, 13720504 frames, score 22, max score 773
# Completed 4895 games, 62345 rewards, 13722673 frames, score 5, max score 773
# Completed 4896 games, 62490 rewards, 13748983 frames, score 144, max score 773
# Completed 4897 games, 62515 rewards, 13759023 frames, score 24, max score 773
# Completed 4898 games, 62542 rewards, 13763974 frames, score 26, max score 773
# Completed 4899 games, 62598 rewards, 13772898 frames, score 55, max score 773
# Completed 4900 games, 62623 rewards, 13783275 frames, score 24, max score 773
# Completed 4901 games, 62674 rewards, 13799445 frames, score 50, max score 773
# Completed 4902 games, 62748 rewards, 13816221 frames, score 73, max score 773
# Completed 4903 games, 62752 rewards, 13816914 frames, score 3, max score 773
# Completed 4904 games, 62823 rewards, 13837084 frames, score 70, max score 773
# Completed 4905 games, 62850 rewards, 13850319 frames, score 26, max score 773
# Completed 4906 games, 62899 rewards, 13865776 frames, score 48, max score 773
# Completed 4907 games, 62903 rewards, 13866418 frames, score 3, max score 773
# Completed 4908 games, 62927 rewards, 13871727 frames, score 23, max score 773
# Completed 4909 games, 62970 rewards, 13878470 frames, score 42, max score 773
# Completed 4910 games, 62979 rewards, 13880961 frames, score 8, max score 773
# Completed 4911 games, 62987 rewards, 13882900 frames, score 7, max score 773
# Completed 4912 games, 63005 rewards, 13886665 frames, score 17, max score 773
# Completed 4913 games, 63014 rewards, 13888891 frames, score 8, max score 773
# Completed 4914 games, 63024 rewards, 13890455 frames, score 9, max score 773
# Completed 4915 games, 63036 rewards, 13892368 frames, score 11, max score 773
# Completed 4916 games, 63054 rewards, 13898537 frames, score 17, max score 773
# Completed 4917 games, 63072 rewards, 13902357 frames, score 17, max score 773
# Completed 4918 games, 63075 rewards, 13903086 frames, score 2, max score 773
# Completed 4919 games, 63081 rewards, 13904369 frames, score 5, max score 773
# Completed 4920 games, 63083 rewards, 13905031 frames, score 1, max score 773
# Completed 4921 games, 63119 rewards, 13913433 frames, score 35, max score 773
# Completed 4922 games, 63145 rewards, 13917511 frames, score 25, max score 773
# Completed 4923 games, 63165 rewards, 13920508 frames, score 19, max score 773
# Completed 4924 games, 63178 rewards, 13923213 frames, score 12, max score 773
# Completed 4925 games, 63215 rewards, 13930970 frames, score 36, max score 773
# Completed 4926 games, 63253 rewards, 13941427 frames, score 37, max score 773
# Completed 4927 games, 63262 rewards, 13942984 frames, score 8, max score 773
# Completed 4928 games, 63266 rewards, 13943946 frames, score 3, max score 773
# Completed 4929 games, 63296 rewards, 13949621 frames, score 29, max score 773
# Completed 4930 games, 63308 rewards, 13951983 frames, score 11, max score 773
# Completed 4931 games, 63310 rewards, 13952645 frames, score 1, max score 773
# Completed 4932 games, 63318 rewards, 13954131 frames, score 7, max score 773
# Completed 4933 games, 63328 rewards, 13956994 frames, score 9, max score 773
# Completed 4934 games, 63338 rewards, 13958693 frames, score 9, max score 773
# Completed 4935 games, 63364 rewards, 13965973 frames, score 25, max score 773
# Completed 4936 games, 63369 rewards, 13966847 frames, score 4, max score 773
# Completed 4937 games, 63375 rewards, 13967939 frames, score 5, max score 773
# Completed 4938 games, 63381 rewards, 13969296 frames, score 5, max score 773
# Completed 4939 games, 63443 rewards, 13996364 frames, score 61, max score 773
# Completed 4940 games, 63474 rewards, 14001985 frames, score 30, max score 773
# Completed 4941 games, 63482 rewards, 14003280 frames, score 7, max score 773
# Completed 4942 games, 63518 rewards, 14010412 frames, score 35, max score 773
# Completed 4943 games, 63531 rewards, 14014615 frames, score 12, max score 773
# Completed 4944 games, 63553 rewards, 14017831 frames, score 21, max score 773
# Completed 4945 games, 63647 rewards, 14034025 frames, score 93, max score 773
# Completed 4946 games, 63664 rewards, 14036620 frames, score 16, max score 773
# Completed 4947 games, 63670 rewards, 14037879 frames, score 5, max score 773
# Completed 4948 games, 63684 rewards, 14040253 frames, score 13, max score 773
# Completed 4949 games, 63720 rewards, 14045755 frames, score 35, max score 773
# Completed 4950 games, 63746 rewards, 14050180 frames, score 25, max score 773
# Completed 4951 games, 63762 rewards, 14052680 frames, score 15, max score 773
# Completed 4952 games, 63786 rewards, 14057117 frames, score 23, max score 773
# Completed 4953 games, 63793 rewards, 14058375 frames, score 6, max score 773
# Completed 4954 games, 63808 rewards, 14061276 frames, score 14, max score 773
# Completed 4955 games, 63809 rewards, 14061484 frames, score 0, max score 773
# Completed 4956 games, 63812 rewards, 14062237 frames, score 2, max score 773
# Completed 4957 games, 63844 rewards, 14069699 frames, score 31, max score 773
# Completed 4958 games, 63855 rewards, 14071636 frames, score 10, max score 773
# Completed 4959 games, 63883 rewards, 14075991 frames, score 27, max score 773
# Completed 4960 games, 63892 rewards, 14077353 frames, score 8, max score 773
# Completed 4961 games, 63900 rewards, 14080253 frames, score 7, max score 773
# Completed 4962 games, 63925 rewards, 14084529 frames, score 24, max score 773
# Completed 4963 games, 63941 rewards, 14087138 frames, score 15, max score 773
# Completed 4964 games, 63964 rewards, 14091185 frames, score 22, max score 773
# Completed 4965 games, 63974 rewards, 14093134 frames, score 9, max score 773
# Completed 4966 games, 63983 rewards, 14094744 frames, score 8, max score 773
# Completed 4967 games, 63998 rewards, 14097713 frames, score 14, max score 773
# Completed 4968 games, 64005 rewards, 14099232 frames, score 6, max score 773
# Completed 4969 games, 64014 rewards, 14100837 frames, score 8, max score 773
# Completed 4970 games, 64020 rewards, 14101742 frames, score 5, max score 773
# Completed 4971 games, 64028 rewards, 14103386 frames, score 7, max score 773
# Completed 4972 games, 64030 rewards, 14103727 frames, score 1, max score 773
# Completed 4973 games, 64035 rewards, 14105012 frames, score 4, max score 773
# Completed 4974 games, 64047 rewards, 14107210 frames, score 11, max score 773
# Completed 4975 games, 64067 rewards, 14110188 frames, score 19, max score 773
# Completed 4976 games, 64070 rewards, 14110869 frames, score 2, max score 773
# Completed 4977 games, 64095 rewards, 14115192 frames, score 24, max score 773
# Completed 4978 games, 64110 rewards, 14117473 frames, score 14, max score 773
# Completed 4979 games, 64133 rewards, 14127105 frames, score 22, max score 773
# Completed 4980 games, 64139 rewards, 14128148 frames, score 5, max score 773
# Completed 4981 games, 64194 rewards, 14145207 frames, score 54, max score 773
# Completed 4982 games, 64196 rewards, 14145574 frames, score 1, max score 773
# Completed 4983 games, 64209 rewards, 14150944 frames, score 12, max score 773
# Completed 4984 games, 64218 rewards, 14152600 frames, score 8, max score 773
# Completed 4985 games, 64225 rewards, 14154525 frames, score 6, max score 773
# Completed 4986 games, 64228 rewards, 14155082 frames, score 2, max score 773
# Completed 4987 games, 64230 rewards, 14155496 frames, score 1, max score 773
# Completed 4988 games, 64242 rewards, 14157308 frames, score 11, max score 773
# Completed 4989 games, 64273 rewards, 14164536 frames, score 30, max score 773
# Completed 4990 games, 64282 rewards, 14171172 frames, score 8, max score 773
# Completed 4991 games, 64289 rewards, 14172370 frames, score 6, max score 773
# Completed 4992 games, 64291 rewards, 14172858 frames, score 1, max score 773
# Completed 4993 games, 64295 rewards, 14173801 frames, score 3, max score 773
# Completed 4994 games, 64300 rewards, 14174823 frames, score 4, max score 773
# Completed 4995 games, 64307 rewards, 14175967 frames, score 6, max score 773
# Completed 4996 games, 64309 rewards, 14176430 frames, score 1, max score 773
# Completed 4997 games, 64322 rewards, 14178403 frames, score 12, max score 773
# Completed 4998 games, 64369 rewards, 14191493 frames, score 46, max score 773
# Completed 4999 games, 64382 rewards, 14194071 frames, score 12, max score 773
# The number of games played was 5000
# The number of video frames was 5000
# The size of each returned Q-matrix was (0,)

# %% [markdown]
# Now let's plot the score, to see if it improved over time.  We will also plot the local average, averaged over 10 consecutive games, to see if that has improved.  Notice that we can use `np.convolve` to compute the local average.
#
# These numbers are really noisy, with a really large maximum.  We will plot `np.log10(1+x)`, rather than x, so that we can better see the average numbers, and ignore the very large noisy spikes.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,9),layout='tight')
ax = [ fig.add_subplot(3,1,x) for x in range(1,4) ]
ax[0].plot(np.arange(0,len(scores)),np.log10(1+np.array(scores)))
ax[0].plot([0,5000],np.log10([7,7]),'k--')
ax[0].set_title('Game scores')
ax[1].plot(np.arange(4991),np.log10(1+np.convolve(np.ones(10)/10,scores,mode='valid')))
ax[1].plot([0,4991],np.log10([7,7]),'k--')
ax[1].set_title('Game scores, average 10 consecutive games')
ax[2].plot(np.arange(0,len(q_achieved)),q_achieved)
ax[2].set_title('Q values of state achieved at each time')
ax[2].set_ylabel('Game number')
# Out:
# Text(0, 0.5, 'Game number')

# %% [markdown]
# Hooray, it has learned!  If you are getting a ten-game average score of better than 6, then you are ready to submit your model for grading.   In order to do that, you need to save the model:

# %%
q_learner.save('trained_model.npz')

# %% [markdown]
# <a id='section9'></a>

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# For extra credit, download the file <a href="mp11_extra.zip">mp11_extra.zip</a>.  The only important file in this package is:
# * `tests/test_extra.py`: this contains extra tests that will evaluate your pre-trained `deep_q` learner, which should be in a file called `trained_model.pkl`.  For full credit, your model should achieve an average score of greater than 20, averaged over 10 consecutive games.
#
# With a quantized lookup table, it's probably not possible to achieve an average score of 20.  With a deep-Q learner, however, it is eminently possible.  In order to do the extra credit, therefore, you should just fill in the part of `submitted.py` that implements the `deep_q` learner, using pytorch to define a model structure, train it, save it, load it, and act on it.  This learner only needs to have five methods: `__init__`, `act`, `learn`, `save`, and `load`:

# %%
importlib.reload(submitted)
help(submitted.deep_q.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst)
#     Initialize self.  See help(type(self)) for accurate signature.

# %%
help(submitted.deep_q.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)

# %%
help(submitted.deep_q.learn)

# %%
help(submitted.deep_q.save)

# %%
help(submitted.deep_q.load)

# %% [markdown]
# <a id='grade'></a>

# %% [markdown]
# ## Grade your homework

# %% [markdown]
# If you've reached this point, and all of the above sections work, then you're ready to try grading your homework!  Before you submit it to Gradescope, try grading it on your own machine.  This will run some visible test cases (which you can read in `tests/test_visible.py`), and compare the results to the solutions (which you can read in `solution.json`).
#
# The exclamation point (!) tells python to run the following as a shell command.  Obviously you don't need to run the code this way -- this usage is here just to remind you that you can also, if you wish, run this command in a terminal window.

# %%
# !python3 grade.py
# Out:
# .....Completed 0 games, 4 rewards, 1108 frames, score 3, max score 3
# Completed 1 games, 7 rewards, 1939 frames, score 2, max score 3
# Completed 2 games, 9 rewards, 2322 frames, score 1, max score 3
# Completed 3 games, 13 rewards, 3475 frames, score 3, max score 3
# Completed 4 games, 19 rewards, 4569 frames, score 5, max score 5
# Completed 5 games, 32 rewards, 8607 frames, score 12, max score 12
# Completed 6 games, 36 rewards, 9546 frames, score 3, max score 12
# Completed 7 games, 43 rewards, 11180 frames, score 6, max score 12
# Completed 8 games, 49 rewards, 13226 frames, score 5, max score 12
# Completed 9 games, 82 rewards, 22140 frames, score 32, max score 32
# .
# ----------------------------------------------------------------------
# Ran 6 tests in 0.359s
#
# OK

# %% [markdown]
# Now you should try uploading your code to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
#
# **Warning:** For this MP you need to update two files, not just one.
# * `trained_model.npz` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
#
# **Warning:** The autograder calculates the average score over ten random games.  If you are getting an average score above 10 almost all the time on your own computer, and if the autograder says you had a score below 10, try resubmitting to see if the next round of random games is better.
#
# **Extra Credit:** Your extra credit should also be uploaded as two files,
# * `trained_model.pkl` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
